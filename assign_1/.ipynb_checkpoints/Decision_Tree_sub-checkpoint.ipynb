# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from pprint import pprint
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
# %matplotlib inline
# %matplotlib notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Read data and convert categorical to numerical
# Read the given data. There are some categorical feilds convert them to numerical field.

# %%
df = pd.read_csv("train.csv")
original_data = df

# %%
def convert_categorical_to_numerical(data):
    res = pd.factorize(data)
    x, y = res
    return x, y

# %%
array, convert_back_sales_to_categorical = convert_categorical_to_numerical(
    df['sales'])
df['sales'] = array
array, convert_back_salary_to_categorical = convert_categorical_to_numerical(
    df['salary'])
df['salary'] = array

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.10             0.90               7                   286
# 1                0.89             0.93               4                   249
# 2                0.38             0.50               2                   132
# 3                0.95             0.71               4                   151
# 4                0.84             0.84               5                   163
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   4              0     1                      0      0
# 1                   3              0     0                      0      0
# 2                   3              0     1                      0      1
# 3                   4              0     0                      0      0
# 4                   3              0     0                      0      2
#
#    salary
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        11238.000000     11238.000000    11238.000000
# mean             0.611518         0.716246        3.811176
# std              0.247939         0.170822        1.234581
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.810000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          11238.000000        11238.000000   11238.000000  11238.000000
# mean             200.930415            3.487720       0.145666      0.238032
# std               49.876282            1.462832       0.352787      0.425898
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              199.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years         sales        salary
# count           11238.000000  11238.000000  11238.000000
# mean                0.020911      3.488343      0.596014
# std                 0.143093      3.127870      0.639807
# min                 0.000000      0.000000      0.000000
# 25%                 0.000000      0.000000      0.000000
# 50%                 0.000000      2.000000      1.000000
# 75%                 0.000000      6.000000      1.000000
# max                 1.000000      9.000000      2.000000

# %%
result = pd.read_csv('sample_test.csv')

# %%
result
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.69             0.69               3                   236
# 1                0.36             0.54               2                   153
#
#    time_spend_company  Work_accident  promotion_last_5years        sales  \
# 0                   4              0                      0  product_mng
# 1                   3              1                      0   accounting
#
#    salary
# 0  medium
# 1  medium

# %% [markdown]
# # Analyse data if there is some pattern
# The step one of machine learning is to study data. Visualise if there are any patterns between data. if any field is more important to the result.study the corelation between the fields.

# %%
df['satisfaction_level'].hist(bins=50)

# %%
print(df.groupby('sales').size())
print(df.groupby('left').size())
print(df.groupby('Work_accident').size())
# Out:
# sales
# 0    3151
# 1     583
# 2    2001
# 3     474
# 4     926
# 5     682
# 6     625
# 7     577
# 8    1679
# 9     540
# dtype: int64
# left
# 0    8563
# 1    2675
# dtype: int64
# Work_accident
# 0    9601
# 1    1637
# dtype: int64

# %%
sns.pairplot(df, hue='left')

# %%
from pandas.plotting import scatter_matrix
# scatter plot matrix
scatter_matrix(df, figsize=(10, 10))
plt.pyplot.show()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb68ba58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb1e4d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdae88470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdae96e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdacf21d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdacf2208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb15f7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb101cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb12d3c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb0d3a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb087128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9bdb0af7b8>]],
#       dtype=object)

# %% [markdown]
# # Split data into test and training set
# Split given data into training and testing data. The given data has 11K rows so a good split is around 80%. Split function is randomly selects 80% of rows and label them as training data while rest is termed as testing data.

# %%
def split_test_train(X, y, percent=0.8):
    mask = np.random.rand(len(df)) < percent
    X_train = X[mask]
    X_test = X[~mask]
    y_train = y[mask]
    y_test = y[~mask]
    print(X_train.shape, X_test.shape)
    return X_train, X_test, y_train, y_test

# %%
data_categorical = df[[
    'Work_accident', 'sales', 'promotion_last_5years', 'salary', 'left'
]]
X_categorical = data_categorical.drop('left', axis=1)
y_categorical = data_categorical[['left']]
X_train_cat, X_test_cat, y_train_cat, y_test_cat = split_test_train(
    X_categorical, y_categorical, 0.85)
train_data_categorical = X_train_cat
train_data_categorical['left'] = y_train_cat
# Out:
# (9548, 4) (1690, 4)
# /home/aman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
X_full = df.drop('left', axis=1)
y_full = df[['left']]
X_train, X_test, y_train, y_test = split_test_train(X_full, y_full, 0.8)
train_df = X_train.copy()
train_df['left'] = y_train
print(X_train.shape, X_test.shape)
# Out:
# (8969, 9) (2269, 9)
# (8969, 9) (2269, 9)

# %% [markdown]
# # Classes for Node and Decision Tree
# ## Node Class
# Node class contain the data relevant to a node of the tree. The main feilds include
# - Name (The field on the basis of which we'll have to traverse down the tree)
# - information_gain (The information gain at this node)
# - leaf (Boolean variable denoting leaf)
# - target (If leaf then class to which the node belongs)
# - value (The value on which split was made)
# - class_count (Dictionary to store the number of elements class wise)
# - categorical (Boolean variable denoting whether split was made categorical or continous)
# - split_val (If not categorical then split value)
#
# ## Decision_tree
# Simple class with init, update and add children function only.

# %%
class Node:
    def __init__(self,
                 name=None,
                 information_gain=0,
                 leaf=False,
                 target=None,
                 value=None,
                 class_count=None,
                 categorical=True,
                 split_val=0.0):
        self.name = name
        self.information_gain = information_gain
        self.leaf = leaf
        self.target = target
        self.value = value
        self.class_count = class_count
        self.categorical = categorical
        self.split_val = split_val

    def update(self,
               name,
               information_gain,
               leaf=False,
               target=None,
               value=None,
               class_count=None):
        self.name = name
        self.information_gain = information_gain
        self.leaf = leaf
        self.target = target
        self.value = value
        self.class_count = class_count

    def print_node(self):
        print(
            "value = {0}, name = {1}, info_gain = {2},  leaf = {3}, target = {4}, class_count = {5}, split_val = {6}"
            .format(self.value, self.name, self.information_gain, self.leaf,
                    self.target, self.class_count, self.split_val))

# %%
class Decision_tree:
    def __init__(self, node=None):
        if not node:
            self.root = Node()
        else:
            self.root = node
        self.children = {}

    def add_children(self, child, value):
        self.children[value] = child

    def update(self,
               name=None,
               information_gain=0,
               leaf=False,
               target=None,
               value=None,
               class_count=None):
        self.root.update(name, information_gain, leaf, target, value,
                         class_count)

# %% [markdown]
# # Helper Functions
# ### evaluate_result
# This function takes two arguments y_test(original values), y_pred(predicted values) It prints the tn, fp, fn, tp, accuracy, f1_score, precision_score, recall_score. Also returns the f1_score, precision score, recall score and accuracy score.
# ### find_entropy
# It takes the target as input and returns the entropy.
# ### find_gini_index
# It takes the target as input and returns the gini index.
# ### find_misclassification
# It takes the target as input and returns the misclassification.

# %%
def evaluate_result(y_test, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("tn = {0}, fp = {1}, fn = {2}, tp = {3}".format(tn, fp, fn, tp))
    f1 = f1_score(y_test, y_pred, average="macro")
    print("f1_score\t : ", f1)
    ps = precision_score(y_test, y_pred, average="macro")
    print("precision_score\t : ", ps)
    rs = recall_score(y_test, y_pred, average="macro")
    print("recall_score\t : ", rs)
    acs = accuracy_score(y_test, y_pred)
    print("accuracy_score\t : ", acs)
    return f1, ps, rs, acs

# %%
def find_entropy(target):
    #     print("in entropy")
    elements, counts = np.unique(target, return_counts=True)
    if len(elements) == 0:
        return 0
    entropy = np.sum(
        [(-entry / np.sum(counts)) * np.log2(entry / np.sum(counts))
         for entry in counts])
    return entropy

# %%
def find_gini_index(target):
    #     print("i was called")
    elements, counts = np.unique(target, return_counts=True)
    #     print(counts)
    if len(elements) == 0:
        return 0
    gini_index = np.sum([(entry / np.sum(counts))**2 for entry in counts])
    return 1 - gini_index

# %%
def find_misclassification(target):
    elements, counts = np.unique(target, return_counts=True)
    if len(elements) == 0:
        return 0
    misclassification = np.max([(-entry / np.sum(counts)) for entry in counts])
    return 1 - misclassification

# %%
find_entropy(train_data_categorical['left'])
# Out:
# 0.7914728009196683

# %% [markdown]
# # Part 1 : Categorical Decision Tree
# Decision trees are supervised learning algorithms used for both, classification and regression tasks where we will concentrate on classification in this first part of our decision tree tutorial.
# The main idea of decision trees is to find those descriptive features which contain the most "information" regarding the target feature and then split the dataset along the values of these features such that the target feature values for the resulting sub_datasets are as pure as possible. The descriptive feature which leaves the target feature most purely is said to be the most informative one. This process of finding the "most informative" feature is done until we accomplish a stopping criteria where we then finally end up in so called leaf nodes. The leaf nodes contain the predictions we will make for new query instances presented to our trained model. This is possible since the model has kind of learned the underlying structure of the training data and hence can, given some assumptions, make predictions about the target feature value (class) of unseen query instances.
#
# ### Training:
# For training the model the whole dataset is passed to a recursive function. Data recieved at any point of time can either be pure dor impure. Pure data means that all the entries belong to the same class. While the impure data contain the entries from more than one classes. Whenever we encounter an impure data. We will split the data into multiple smaller datasets, number of unique values in the class with maximum information gain. Which indeed would be calulated some error function for calculation. The data is splitted such that the information gain is maximized. Then the function is called recursively over the newly splitted data.
# Base cases: Whenver the length of data become 0, or we encounter a pure class.
#
# ### Testing:
# For Testing we need to a simple traversal in the above formed decision tree. The class at the leaf would be the class of the test row. If somehow we encounter data such that there is no path fromm the current node. We will then traverse the whole tree according to the values from there. While doing so if we encounter leaf nodes we will send the counts of class samples ther. After reciving such counts from all  possible paths. We will accumulate and declare the test as the maximum value among the accumulated results.

# %%
def info_gain(df, split_attribute, target, error_function=find_entropy):
    parent_entropy = error_function(df[target])
    vals, counts = np.unique(df[split_attribute], return_counts=True)
    weighted_entropy = np.sum([(child_count / np.sum(counts)) * error_function(
        df.where(df[split_attribute] == child_value).dropna()[target])
                               for (child_value,
                                    child_count) in zip(vals, counts)])
    information_gain = parent_entropy - weighted_entropy
    return information_gain

# %%
info_gain(train_data_categorical, 'salary', 'left')
# Out:
# 0.021933541906749454

# %%
def ID3(df, original_df, features, target, parent_node_class=None):
    count = convert_zip_to_dict(zip(np.unique(df[target], return_counts=True)))
    if len(np.unique(df[target])) <= 1:
        return Decision_tree(
            Node(None, 0, True,
                 np.unique(df[target])[0], parent_node_class, count))


#     elif len(df) == 0:
#         return Decision_tree(Node(leaf = True, target = np.unique(original_df[target])[np.argmax(np.unique(original_df[target],return_counts=True)[1])], value = parent_node_class))
    elif len(features) == 0:
        return Decision_tree(
            Node(
                leaf=True,
                target=np.unique(df[target])[np.argmax(
                    np.unique(df[target], return_counts=True)[1])],
                value=parent_node_class,
                class_count=count))
    else:
        item_values = [info_gain(df, feature, target) for feature in features]
        best_feature_index = np.argmax(item_values)
        best_feature = features[best_feature_index]
        tree = Decision_tree()
        tree.update(
            name=best_feature,
            information_gain=np.max(item_values),
            value=parent_node_class,
            class_count=count)
        features = [i for i in features if i != best_feature]

        for value in np.unique(df[best_feature]):
            child_df = df.where(df[best_feature] == value).dropna()
            sub_tree = ID3(
                child_df,
                original_df,
                features,
                target,
                parent_node_class=value)
            tree.add_children(sub_tree, value)

        return tree

# %%
dec_tree = ID3(train_data_categorical, train_data_categorical,
               ['Work_accident', 'sales', 'promotion_last_5years', 'salary'],
               'left')

# %%
def inorder(x, indent=0):
    pre = "\t" * indent
    print(pre, end="")
    x.root.print_node()
    weight = 1
    for value, child in x.children.items():
        weight += inorder(child, indent + 1)
    return weight

# %%
inorder(dec_tree)
# Out:
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# 	value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# 		value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 9, 1.0: 1}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.002634499136146662,  leaf = False, target = None, class_count = {0.0: 142, 1.0: 65}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 141, 1.0: 65}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 2.0, name = promotion_last_5years, info_gain = 2.995864099075707e-05,  leaf = False, target = None, class_count = {0.0: 497, 1.0: 214}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 493, 1.0: 212}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4, 1.0: 2}, split_val = 0.0
# 			value = 3.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 63, 1.0: 35}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 63, 1.0: 35}, split_val = 0.0
# 			value = 4.0, name = promotion_last_5years, info_gain = 0.009299606756971945,  leaf = False, target = None, class_count = {0.0: 235, 1.0: 114}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235, 1.0: 112}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 			value = 5.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 186, 1.0: 70}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 186, 1.0: 70}, split_val = 0.0
# 			value = 6.0, name = promotion_last_5years, info_gain = 0.012906796443777346,  leaf = False, target = None, class_count = {0.0: 130, 1.0: 74}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 126, 1.0: 74}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 			value = 7.0, name = promotion_last_5years, info_gain = 0.002918398103925357,  leaf = False, target = None, class_count = {0.0: 144, 1.0: 27}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 142, 1.0: 27}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 			value = 8.0, name = promotion_last_5years, info_gain = 0.0032392475992879532,  leaf = False, target = None, class_count = {0.0: 388, 1.0: 225}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 385, 1.0: 225}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 			value = 9.0, name = promotion_last_5years, info_gain = 0.0032887083867493283,  leaf = False, target = None, class_count = {0.0: 118, 1.0: 58}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 117, 1.0: 58}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 		value = 1.0, name = sales, info_gain = 0.006838903972570032,  leaf = False, target = None, class_count = {0.0: 618, 1.0: 67}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.00913705542636939,  leaf = False, target = None, class_count = {0.0: 172, 1.0: 16}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 171, 1.0: 15}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1, 1.0: 1}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 28, 1.0: 2}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 28, 1.0: 2}, split_val = 0.0
# 			value = 2.0, name = promotion_last_5years, info_gain = 0.0034149609319238383,  leaf = False, target = None, class_count = {0.0: 102, 1.0: 15}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 100, 1.0: 15}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 			value = 3.0, name = promotion_last_5years, info_gain = 0.02008994082044896,  leaf = False, target = None, class_count = {0.0: 16, 1.0: 2}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 14, 1.0: 2}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 			value = 4.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 54, 1.0: 4}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54, 1.0: 4}, split_val = 0.0
# 			value = 5.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 45, 1.0: 3}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 45, 1.0: 3}, split_val = 0.0
# 			value = 6.0, name = promotion_last_5years, info_gain = 0.007184531460440957,  leaf = False, target = None, class_count = {0.0: 33, 1.0: 3}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 31, 1.0: 3}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 			value = 7.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 43, 1.0: 3}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 43, 1.0: 3}, split_val = 0.0
# 			value = 8.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 102, 1.0: 17}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 102, 1.0: 17}, split_val = 0.0
# 			value = 9.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 2}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 23, 1.0: 2}, split_val = 0.0
# 	value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# 		value = 0.0, name = Work_accident, info_gain = 0.013160456099564843,  leaf = False, target = None, class_count = {0.0: 938, 1.0: 190}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.010317305704401702,  leaf = False, target = None, class_count = {0.0: 772, 1.0: 179}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 740, 1.0: 179}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 32}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.009363000723079884,  leaf = False, target = None, class_count = {0.0: 166, 1.0: 11}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 149, 1.0: 11}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 17}, split_val = 0.0
# 		value = 1.0, name = Work_accident, info_gain = 0.00862678866413269,  leaf = False, target = None, class_count = {0.0: 159, 1.0: 59}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.00776868874892267,  leaf = False, target = None, class_count = {0.0: 136, 1.0: 55}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 133, 1.0: 55}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 4}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 23, 1.0: 4}, split_val = 0.0
# 		value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 8}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.0015587202980803516,  leaf = False, target = None, class_count = {0.0: 93, 1.0: 11}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 92, 1.0: 11}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 		value = 3.0, name = promotion_last_5years, info_gain = 0.012016859826316173,  leaf = False, target = None, class_count = {0.0: 122, 1.0: 16}, split_val = 0.0
# 			value = 0.0, name = Work_accident, info_gain = 0.002736361250707753,  leaf = False, target = None, class_count = {0.0: 113, 1.0: 16}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 91, 1.0: 14}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 22, 1.0: 2}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 9}, split_val = 0.0
# 		value = 4.0, name = Work_accident, info_gain = 0.02119281448546051,  leaf = False, target = None, class_count = {0.0: 265, 1.0: 50}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.009121700820504453,  leaf = False, target = None, class_count = {0.0: 224, 1.0: 49}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 224, 1.0: 48}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 1}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 41, 1.0: 1}, split_val = 0.0
# 		value = 5.0, name = Work_accident, info_gain = 0.012071018489614227,  leaf = False, target = None, class_count = {0.0: 174, 1.0: 54}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 148, 1.0: 51}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 148, 1.0: 51}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 26, 1.0: 3}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 26, 1.0: 3}, split_val = 0.0
# 		value = 6.0, name = promotion_last_5years, info_gain = 0.0229221500706821,  leaf = False, target = None, class_count = {0.0: 189, 1.0: 48}, split_val = 0.0
# 			value = 0.0, name = Work_accident, info_gain = 0.0022178178773603063,  leaf = False, target = None, class_count = {0.0: 173, 1.0: 48}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 143, 1.0: 42}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 30, 1.0: 6}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 16}, split_val = 0.0
# 		value = 7.0, name = Work_accident, info_gain = 0.02329972295304228,  leaf = False, target = None, class_count = {0.0: 198, 1.0: 38}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.018324801689852177,  leaf = False, target = None, class_count = {0.0: 163, 1.0: 37}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 151, 1.0: 37}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.004791113356737514,  leaf = False, target = None, class_count = {0.0: 35, 1.0: 1}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 31, 1.0: 1}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 		value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 6.160268509980416e-05,  leaf = False, target = None, class_count = {0.0: 410, 1.0: 99}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 403, 1.0: 97}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 7, 1.0: 2}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.0014347498645947976,  leaf = False, target = None, class_count = {0.0: 84, 1.0: 8}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 83, 1.0: 8}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 		value = 9.0, name = Work_accident, info_gain = 0.030461992142234995,  leaf = False, target = None, class_count = {0.0: 144, 1.0: 83}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.014334436374153547,  leaf = False, target = None, class_count = {0.0: 124, 1.0: 81}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 120, 1.0: 81}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 			value = 1.0, name = promotion_last_5years, info_gain = 0.006404117697611511,  leaf = False, target = None, class_count = {0.0: 20, 1.0: 2}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 19, 1.0: 2}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 	value = 2, name = sales, info_gain = 0.025607838985328535,  leaf = False, target = None, class_count = {0.0: 771, 1.0: 53}, split_val = 0.0
# 		value = 0.0, name = Work_accident, info_gain = 0.006867146863459489,  leaf = False, target = None, class_count = {0.0: 176, 1.0: 7}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0028162527492600065,  leaf = False, target = None, class_count = {0.0: 155, 1.0: 7}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 148, 1.0: 7}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 7}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 21}, split_val = 0.0
# 		value = 1.0, name = Work_accident, info_gain = 0.019227366297796866,  leaf = False, target = None, class_count = {0.0: 53, 1.0: 3}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.009727494624461375,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 3}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 37, 1.0: 3}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 		value = 2.0, name = Work_accident, info_gain = 0.03381770674629325,  leaf = False, target = None, class_count = {0.0: 110, 1.0: 17}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 91, 1.0: 17}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 91, 1.0: 17}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 19}, split_val = 0.0
# 		value = 3.0, name = promotion_last_5years, info_gain = 0.0019430064653108217,  leaf = False, target = None, class_count = {0.0: 148, 1.0: 1}, split_val = 0.0
# 			value = 0.0, name = Work_accident, info_gain = 0.0018961236528205472,  leaf = False, target = None, class_count = {0.0: 121, 1.0: 1}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 103, 1.0: 1}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 27}, split_val = 0.0
# 		value = 4.0, name = Work_accident, info_gain = 0.0023098773746043078,  leaf = False, target = None, class_count = {0.0: 49, 1.0: 2}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 47, 1.0: 2}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 47, 1.0: 2}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 		value = 5.0, name = Work_accident, info_gain = 0.03911850518872095,  leaf = False, target = None, class_count = {0.0: 42, 1.0: 5}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 32, 1.0: 5}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 32, 1.0: 5}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 10}, split_val = 0.0
# 		value = 6.0, name = Work_accident, info_gain = 0.04102181215980544,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 5}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.006084075141995493,  leaf = False, target = None, class_count = {0.0: 31, 1.0: 5}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 30, 1.0: 5}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 10}, split_val = 0.0
# 		value = 7.0, name = Work_accident, info_gain = 0.03299334509746393,  leaf = False, target = None, class_count = {0.0: 30, 1.0: 3}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.006946098000366274,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 3}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 22, 1.0: 3}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 7}, split_val = 0.0
# 		value = 8.0, name = Work_accident, info_gain = 0.021516514585765867,  leaf = False, target = None, class_count = {0.0: 98, 1.0: 6}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 75, 1.0: 6}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 75, 1.0: 6}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 23}, split_val = 0.0
# 		value = 9.0, name = Work_accident, info_gain = 0.02532496193896483,  leaf = False, target = None, class_count = {0.0: 24, 1.0: 4}, split_val = 0.0
# 			value = 0.0, name = promotion_last_5years, info_gain = 0.010288029858146253,  leaf = False, target = None, class_count = {0.0: 21, 1.0: 4}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 20, 1.0: 4}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 166

# %%
def predict_exception(query, tree):
    print("in predict exception: ", query)
    tree.root.print_node()
    if tree.root.leaf is True:
        print(list(tree.root.class_count))
        return dict(tree.root.class_count)
    if query[tree.root.name] in tree.children.keys():
        return predict_exception(query, tree.children[query[tree.root.name]])
    answer = {}
    for key, child in tree.children.items():
        res = predict_exception(query, tree.children[key])
        for target, count in res.items():
            if target in answer.keys():
                answer[target] += count
            else:
                answer[target] = count
    print("answer in predict exception: ", answer)
    return answer

# %%
def predict_row(query, tree):
    print("in predict row: ", query)
    tree.root.print_node()
    if tree.root.leaf is True:
        return tree.root.target
    if query[tree.root.name] in tree.children.keys():
        return predict_row(query, tree.children[query[tree.root.name]])
    answer = predict_exception(query, tree)
    print("answer =", answer)
    return max(answer, key=answer.get)

# %%
def test(X, tree):
    #Create new query instances by simply removing the target feature column from the original dataset and
    #convert it to a dictionary
    queries = X.to_dict(orient="records")
    print(len(queries), "####", queries[-1])
    print(len(X))
    #Create a empty DataFrame in whose columns the prediction of the tree are stored
    predicted = []
    #Calculate the prediction accuracy
    for i in range(len(X)):
        print(i)
        res = predict_row(queries[i], tree)
        predicted.append(res)
    return predicted

# %%
# print(X_test_cat.describe())
y_pred = test(X_test_cat, dec_tree)
evaluate_result(y_pred, y_test_cat)
# Out:
# 1699 #### {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# 1699
# 0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.013160456099564843,  leaf = False, target = None, class_count = {0.0: 938, 1.0: 190}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.010317305704401702,  leaf = False, target = None, class_count = {0.0: 772, 1.0: 179}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 740, 1.0: 179}, split_val = 0.0
# 1
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 4.0, name = promotion_last_5years, info_gain = 0.009299606756971945,  leaf = False, target = None, class_count = {0.0: 235, 1.0: 114}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235, 1.0: 112}, split_val = 0.0
# 2
# in predict row:  {'Work_accident': 0, 'sales': 5, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 5, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 5, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 5, 'promotion_last_5years': 0, 'salary': 0}
# value = 5.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 186, 1.0: 70}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 5, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 186, 1.0: 70}, split_val = 0.0
# 3
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 1}
# value = 6.0, name = promotion_last_5years, info_gain = 0.0229221500706821,  leaf = False, target = None, class_count = {0.0: 189, 1.0: 48}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.0022178178773603063,  leaf = False, target = None, class_count = {0.0: 173, 1.0: 48}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 143, 1.0: 42}, split_val = 0.0
# 4
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 1.0, name = sales, info_gain = 0.006838903972570032,  leaf = False, target = None, class_count = {0.0: 618, 1.0: 67}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 4.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 54, 1.0: 4}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54, 1.0: 4}, split_val = 0.0
# 5
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 0}
# value = 7.0, name = promotion_last_5years, info_gain = 0.002918398103925357,  leaf = False, target = None, class_count = {0.0: 144, 1.0: 27}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 142, 1.0: 27}, split_val = 0.0
# 6
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 1, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 1, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 1, 'salary': 1}
# value = 9.0, name = Work_accident, info_gain = 0.030461992142234995,  leaf = False, target = None, class_count = {0.0: 144, 1.0: 83}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 1, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.014334436374153547,  leaf = False, target = None, class_count = {0.0: 124, 1.0: 81}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 1, 'salary': 1}
# value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 7
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 1.0, name = sales, info_gain = 0.006838903972570032,  leaf = False, target = None, class_count = {0.0: 618, 1.0: 67}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00913705542636939,  leaf = False, target = None, class_count = {0.0: 172, 1.0: 16}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 171, 1.0: 15}, split_val = 0.0
# 8
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 2}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 2}
# value = 2, name = sales, info_gain = 0.025607838985328535,  leaf = False, target = None, class_count = {0.0: 771, 1.0: 53}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 2}
# value = 4.0, name = Work_accident, info_gain = 0.0023098773746043078,  leaf = False, target = None, class_count = {0.0: 49, 1.0: 2}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 47, 1.0: 2}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 47, 1.0: 2}, split_val = 0.0
# 9
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 10
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 4.0, name = promotion_last_5years, info_gain = 0.009299606756971945,  leaf = False, target = None, class_count = {0.0: 235, 1.0: 114}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235, 1.0: 112}, split_val = 0.0
# 11
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 12
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 13
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.013160456099564843,  leaf = False, target = None, class_count = {0.0: 938, 1.0: 190}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.010317305704401702,  leaf = False, target = None, class_count = {0.0: 772, 1.0: 179}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 740, 1.0: 179}, split_val = 0.0
# 14
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 2}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 2}
# value = 2, name = sales, info_gain = 0.025607838985328535,  leaf = False, target = None, class_count = {0.0: 771, 1.0: 53}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 2}
# value = 6.0, name = Work_accident, info_gain = 0.04102181215980544,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 5}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = promotion_last_5years, info_gain = 0.006084075141995493,  leaf = False, target = None, class_count = {0.0: 31, 1.0: 5}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 6, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 30, 1.0: 5}, split_val = 0.0
# 15
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 9.0, name = promotion_last_5years, info_gain = 0.0032887083867493283,  leaf = False, target = None, class_count = {0.0: 118, 1.0: 58}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 117, 1.0: 58}, split_val = 0.0
# 16
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 4.0, name = promotion_last_5years, info_gain = 0.009299606756971945,  leaf = False, target = None, class_count = {0.0: 235, 1.0: 114}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235, 1.0: 112}, split_val = 0.0
# 17
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 18
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 2.0, name = promotion_last_5years, info_gain = 2.995864099075707e-05,  leaf = False, target = None, class_count = {0.0: 497, 1.0: 214}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 493, 1.0: 212}, split_val = 0.0
# 19
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 6.160268509980416e-05,  leaf = False, target = None, class_count = {0.0: 410, 1.0: 99}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 403, 1.0: 97}, split_val = 0.0
# 20
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 4.0, name = Work_accident, info_gain = 0.02119281448546051,  leaf = False, target = None, class_count = {0.0: 265, 1.0: 50}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 1.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 1}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 41, 1.0: 1}, split_val = 0.0
# 21
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 2}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 2}
# value = 2, name = sales, info_gain = 0.025607838985328535,  leaf = False, target = None, class_count = {0.0: 771, 1.0: 53}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 2}
# value = 2.0, name = Work_accident, info_gain = 0.03381770674629325,  leaf = False, target = None, class_count = {0.0: 110, 1.0: 17}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 91, 1.0: 17}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 91, 1.0: 17}, split_val = 0.0
# 22
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 4.0, name = Work_accident, info_gain = 0.02119281448546051,  leaf = False, target = None, class_count = {0.0: 265, 1.0: 50}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.009121700820504453,  leaf = False, target = None, class_count = {0.0: 224, 1.0: 49}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 224, 1.0: 48}, split_val = 0.0
# 23
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 24
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 25
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 26
# in predict row:  {'Work_accident': 1, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 1.0, name = sales, info_gain = 0.006838903972570032,  leaf = False, target = None, class_count = {0.0: 618, 1.0: 67}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 2.0, name = promotion_last_5years, info_gain = 0.0034149609319238383,  leaf = False, target = None, class_count = {0.0: 102, 1.0: 15}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 2, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 100, 1.0: 15}, split_val = 0.0
# 27
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 28
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 29
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.013160456099564843,  leaf = False, target = None, class_count = {0.0: 938, 1.0: 190}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.010317305704401702,  leaf = False, target = None, class_count = {0.0: 772, 1.0: 179}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 740, 1.0: 179}, split_val = 0.0
# 30
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 2, name = sales, info_gain = 0.025607838985328535,  leaf = False, target = None, class_count = {0.0: 771, 1.0: 53}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = Work_accident, info_gain = 0.006867146863459489,  leaf = False, target = None, class_count = {0.0: 176, 1.0: 7}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 21}, split_val = 0.0
# 31
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 6.160268509980416e-05,  leaf = False, target = None, class_count = {0.0: 410, 1.0: 99}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 403, 1.0: 97}, split_val = 0.0
# 32
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 33
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1.0, name = promotion_last_5years, info_gain = 0.0014347498645947976,  leaf = False, target = None, class_count = {0.0: 84, 1.0: 8}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 83, 1.0: 8}, split_val = 0.0
# 34
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 35
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 2, name = sales, info_gain = 0.025607838985328535,  leaf = False, target = None, class_count = {0.0: 771, 1.0: 53}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = Work_accident, info_gain = 0.006867146863459489,  leaf = False, target = None, class_count = {0.0: 176, 1.0: 7}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0028162527492600065,  leaf = False, target = None, class_count = {0.0: 155, 1.0: 7}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 2}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 148, 1.0: 7}, split_val = 0.0
# 36
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 1.0, name = promotion_last_5years, info_gain = 0.002634499136146662,  leaf = False, target = None, class_count = {0.0: 142, 1.0: 65}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 141, 1.0: 65}, split_val = 0.0
# 37
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 1}
# value = 7.0, name = Work_accident, info_gain = 0.02329972295304228,  leaf = False, target = None, class_count = {0.0: 198, 1.0: 38}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.018324801689852177,  leaf = False, target = None, class_count = {0.0: 163, 1.0: 37}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 7, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 151, 1.0: 37}, split_val = 0.0
# 38
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 4.0, name = Work_accident, info_gain = 0.02119281448546051,  leaf = False, target = None, class_count = {0.0: 265, 1.0: 50}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 1.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 1}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 41, 1.0: 1}, split_val = 0.0
# 39
# in predict row:  {'Work_accident': 0, 'sales': 3, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 3, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 3, 'promotion_last_5years': 0, 'salary': 1}
# value = 3.0, name = promotion_last_5years, info_gain = 0.012016859826316173,  leaf = False, target = None, class_count = {0.0: 122, 1.0: 16}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 3, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.002736361250707753,  leaf = False, target = None, class_count = {0.0: 113, 1.0: 16}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 3, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 91, 1.0: 14}, split_val = 0.0
# 40
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 41
# in predict row:  {'Work_accident': 0, 'sales': 9, 'promotion_last_5years': 0, 'salary': 2}
# ...
# 1686
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.013160456099564843,  leaf = False, target = None, class_count = {0.0: 938, 1.0: 190}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.010317305704401702,  leaf = False, target = None, class_count = {0.0: 772, 1.0: 179}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 740, 1.0: 179}, split_val = 0.0
# 1687
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 6.160268509980416e-05,  leaf = False, target = None, class_count = {0.0: 410, 1.0: 99}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 403, 1.0: 97}, split_val = 0.0
# 1688
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = promotion_last_5years, info_gain = 0.00228882070489822,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 437}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 0, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 743, 1.0: 436}, split_val = 0.0
# 1689
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1.0, name = promotion_last_5years, info_gain = 0.0014347498645947976,  leaf = False, target = None, class_count = {0.0: 84, 1.0: 8}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 83, 1.0: 8}, split_val = 0.0
# 1690
# in predict row:  {'Work_accident': 1, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 1.0, name = sales, info_gain = 0.006838903972570032,  leaf = False, target = None, class_count = {0.0: 618, 1.0: 67}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 9.0, name = promotion_last_5years, info_gain = 0.0,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 2}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 9, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 23, 1.0: 2}, split_val = 0.0
# 1691
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 6.160268509980416e-05,  leaf = False, target = None, class_count = {0.0: 410, 1.0: 99}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 403, 1.0: 97}, split_val = 0.0
# 1692
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 8.0, name = Work_accident, info_gain = 0.008534175954117984,  leaf = False, target = None, class_count = {0.0: 494, 1.0: 107}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 6.160268509980416e-05,  leaf = False, target = None, class_count = {0.0: 410, 1.0: 99}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 8, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 403, 1.0: 97}, split_val = 0.0
# 1693
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 4.0, name = Work_accident, info_gain = 0.02119281448546051,  leaf = False, target = None, class_count = {0.0: 265, 1.0: 50}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.009121700820504453,  leaf = False, target = None, class_count = {0.0: 224, 1.0: 49}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 224, 1.0: 48}, split_val = 0.0
# 1694
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 4.0, name = promotion_last_5years, info_gain = 0.009299606756971945,  leaf = False, target = None, class_count = {0.0: 235, 1.0: 114}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235, 1.0: 112}, split_val = 0.0
# 1695
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 2.0, name = Work_accident, info_gain = 0.016278131316003974,  leaf = False, target = None, class_count = {0.0: 543, 1.0: 185}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = promotion_last_5years, info_gain = 0.0060927415149516495,  leaf = False, target = None, class_count = {0.0: 450, 1.0: 174}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 2, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 442, 1.0: 174}, split_val = 0.0
# 1696
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 1, name = sales, info_gain = 0.01343230013465646,  leaf = False, target = None, class_count = {0.0: 3226, 1.0: 830}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = Work_accident, info_gain = 0.013160456099564843,  leaf = False, target = None, class_count = {0.0: 938, 1.0: 190}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 1.0, name = promotion_last_5years, info_gain = 0.009363000723079884,  leaf = False, target = None, class_count = {0.0: 166, 1.0: 11}, split_val = 0.0
# in predict row:  {'Work_accident': 1, 'sales': 0, 'promotion_last_5years': 0, 'salary': 1}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 149, 1.0: 11}, split_val = 0.0
# 1697
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 4.0, name = promotion_last_5years, info_gain = 0.009299606756971945,  leaf = False, target = None, class_count = {0.0: 235, 1.0: 114}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 4, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235, 1.0: 112}, split_val = 0.0
# 1698
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = None, name = salary, info_gain = 0.021933541906749454,  leaf = False, target = None, class_count = {0: 7270, 1: 2269}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 0, name = Work_accident, info_gain = 0.028211181655711015,  leaf = False, target = None, class_count = {0.0: 3273, 1.0: 1386}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = sales, info_gain = 0.008220209609144713,  leaf = False, target = None, class_count = {0.0: 2655, 1.0: 1319}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 1.0, name = promotion_last_5years, info_gain = 0.002634499136146662,  leaf = False, target = None, class_count = {0.0: 142, 1.0: 65}, split_val = 0.0
# in predict row:  {'Work_accident': 0, 'sales': 1, 'promotion_last_5years': 0, 'salary': 0}
# value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 141, 1.0: 65}, split_val = 0.0
# tn = 1293, fp = 406, fn = 0, tp = 0
# f1_score	 :  0.4321524064171123
# precision_score	 :  0.5
# recall_score	 :  0.3805179517363155
# accuracy_score	 :  0.761035903472631
# /home/aman/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /home/aman/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# (0.4321524064171123, 0.5, 0.3805179517363155, 0.761035903472631)

# %% [markdown]
# ## Results
# - tn = 1293, fp = 406, fn = 0, tp = 0
# - f1_score	 :  0.4321524064171123
# - precision_score	 :  0.5
# - recall_score	 :  0.3805179517363155
# - accuracy_score	 :  0.761035903472631

# %% [markdown]
# # Part 2: Continuous and Categorical Data
# The main challenge with continous data is that it can't be trained as categorical data. Because it would result in the overfitting of data. As there would be new leaf for almost every data. This would result in almost worst of the decision trees.
# To overcome this we have to split data into two bins. So we will find a thershold, If the value is below that threshold it will go to left otherwise right.
# ### Training:
# For training the model the whole dataset is passed to a recursive function. Data recieved at any point of time can either be pure dor impure. Pure data means that all the entries belong to the same class. While the impure data contain the entries from more than one classes. Whenever we encounter an impure data. We will find the maximum information gain among all the possible columns. For categorical columns we will simply follow the above procedure, indeed we're using the same functions. While for continuous data it was little bit tricky. As it also involves finding the best split even for the column. For that we try every of the unique entry as a split point then evaluated on the basis of information gain. The split with maximum inforamtion gain is choosen as the split for that column.
# Among all the Information gains the split with maximum Information gain is choosen, Then data is splitted accordingly and the fucntion is called on newly splitted data.
# ### Testing:
# We will traverse the tree from root to leaf according to the conditions mentioned below. The class of the test row will be the class of the leaf reached by traversing while adhering to the conditions mentioned below.<br>
# While testing suppose we reach a node. If the attribute which is used for splitting is categorical than the path is choosen accordingly. Otherwise the condition is evaluated. If the data_value is less than split_val we go to the left child otherwise we go to the right child.<br>
# If at node N the value is missing or there is no path for the values in data(categorical) then the whole tree is propogated according to the data from the given node. At leaf nodes the count of each count is returned. All such counts are accumulated at N, the class with maximum count is returned.

# %%
def info_gain_continuous(df,
                         split_attribute,
                         target,
                         split_value,
                         error_function=find_entropy):
    if len(df) == 0:
        print("error")
    parent_entropy = error_function(df[target])
    less_df = df.where(df[split_attribute] <= split_value).dropna()[target]
    greater_df = df.where(df[split_attribute] > split_value).dropna()[target]
    weighted_entropy = (len(less_df) / (len(less_df) + len(greater_df))
                        ) * error_function(less_df)
    weighted_entropy += (len(greater_df) / (len(less_df) + len(greater_df))
                         ) * error_function(greater_df)
    information_gain = parent_entropy - weighted_entropy
    return information_gain

# %%
def find_best_split_for_continuous_attribute(df,
                                             split_feature,
                                             target,
                                             error_function=find_entropy):
    possible_splits = list(np.unique(df[split_feature]))
    if len(possible_splits) == 1:
        return 0, 0
    del possible_splits[-1]
    info_gain = [
        info_gain_continuous(df, split_feature, target, split, error_function)
        for split in possible_splits
    ]
    return np.max(info_gain), possible_splits[np.argmax(info_gain)]

# %%
def ID3_for_continuous(df,
                       original_df,
                       categorical_features,
                       continuous_features,
                       target,
                       parent_node_class=None,
                       max_depth=None,
                       depth=0,
                       error_function=find_entropy):
    count = convert_zip_to_dict(zip(np.unique(df[target], return_counts=True)))
    #     print(len(df), count)
    #     print(depth, max_depth)
    if max_depth == depth:
        return Decision_tree(
            Node(
                leaf=True,
                target=np.unique(df[target])[np.argmax(
                    np.unique(df[target], return_counts=True)[1])],
                value=parent_node_class,
                class_count=count))
    if len(np.unique(df[target])) <= 1:
        return Decision_tree(
            Node(None, 0, True,
                 np.unique(df[target])[0], parent_node_class, count))

    elif len(df) == 0:
        return Decision_tree(
            Node(
                leaf=True,
                target=np.unique(original_df[target])[np.argmax(
                    np.unique(original_df[target], return_counts=True)[1])],
                value=parent_node_class))

    else:
        IG_categorical = [
            info_gain(df, feature, target, error_function)
            for feature in categorical_features
        ]
        IG_continuous = [
            find_best_split_for_continuous_attribute(df, feature, target,
                                                     error_function)
            for feature in continuous_features
        ]
        #         to_remove = []
        #         for i in range(len(IG_continuous)):
        #             if IG_continuous[i][0] == 0:
        #                 to_remove.append(i)
        #                 del continuous_features[i]
        #         for i in to_remove:
        #             del IG_continuous[i]
        IG_categorical.append(0)
        IG_continuous.append((0, 0))
        IG = max(np.max(IG_categorical), max(IG_continuous)[0])
        #         print(len(df), IG, np.max(IG_categorical), max(IG_continuous))
        if IG == 0:
            return Decision_tree(
                Node(
                    leaf=True,
                    target=np.unique(df[target])[np.argmax(
                        np.unique(df[target], return_counts=True)[1])],
                    value=parent_node_class,
                    class_count=count))

        if (np.max(IG_categorical) > max(IG_continuous)[0]):
            best_feature_index = np.argmax(IG_categorical)
            best_feature = categorical_features[best_feature_index]
            tree = Decision_tree()
            tree.update(
                name=best_feature,
                information_gain=np.max(IG_categorical),
                value=parent_node_class,
                class_count=count)
            categorical_features = [
                i for i in categorical_features if i != best_feature
            ]

            for value in np.unique(df[best_feature]):
                child_df = df.where(df[best_feature] == value).dropna()
                sub_tree = ID3_for_continuous(
                    child_df, original_df, categorical_features,
                    continuous_features, target, value, max_depth, depth + 1,
                    error_function)
                tree.add_children(sub_tree, value)
        else:
            best_feature_index = IG_continuous.index(max(IG_continuous))
            best_feature = continuous_features[best_feature_index]
            #             print(best_feature)
            split_val = max(IG_continuous)[1]
            tree = Decision_tree(
                Node(
                    name=best_feature,
                    information_gain=max(IG_continuous)[0],
                    value=parent_node_class,
                    class_count=count,
                    categorical=False,
                    split_val=split_val))
            left_df = df.where(df[best_feature] <= split_val).dropna()
            right_df = df.where(df[best_feature] > split_val).dropna()
            left_child = ID3_for_continuous(
                left_df, original_df, categorical_features,
                continuous_features, target, split_val, max_depth, depth + 1,
                error_function)
            right_child = ID3_for_continuous(
                right_df, original_df, categorical_features,
                continuous_features, target, split_val, max_depth, depth + 1,
                error_function)
            tree.add_children(left_child, 0)
            tree.add_children(right_child, 1)

        return tree

# %%
def predict_exception_continuous(query, tree):
    #     print("in predict exception: ", query)
    #     tree.root.print_node()
    if tree.root.leaf is True:
        return dict(tree.root.class_count)
    if tree.root.categorical:
        if query[tree.root.name] in tree.children.keys():
            return predict_exception_continuous(
                query, tree.children[query[tree.root.name]])
    else:
        child = int(query[tree.root.name] > tree.root.split_val)
        #         print(query[tree.root.name], tree.root.split_val, child)
        return predict_exception_continuous(query, tree.children[child])
    answer = {}
    for key, child in tree.children.items():
        res = predict_exception_continuous(query, tree.children[key])
        for target, count in res.items():
            if target in answer.keys():
                answer[target] += count
            else:
                answer[target] = count


#     print("answer in predict exception: ", answer)
    return answer

# %%
def predict_row_continuous(query, tree):
    #     print("in predict row: ", query)
    #     tree.root.print_node()
    if tree.root.leaf is True:
        return tree.root.target
    if tree.root.categorical:
        if query[tree.root.name] in tree.children.keys():
            return predict_row_continuous(query,
                                          tree.children[query[tree.root.name]])
    else:
        child = query[tree.root.name] > tree.root.split_val
        #         print(query[tree.root.name], tree.root.split_val, child)
        return predict_row_continuous(query, tree.children[child])
    answer = predict_exception_continuous(query, tree)
    #     print("answer =", answer)
    return max(answer, key=answer.get)

# %%
def test_continuous(X, tree):
    #Create new query instances by simply removing the target feature column from the original dataset and
    #convert it to a dictionary
    queries = X.to_dict(orient="records")
    #     print(len(queries), "####", queries[-1])
    #     print(len(X))
    #Create a empty DataFrame in whose columns the prediction of the tree are stored
    predicted = []
    #Calculate the prediction accuracy
    for i in range(len(X)):
        #         print(i)
        res = predict_row_continuous(queries[i], tree)
        predicted.append(res)
    return predicted

# %%
continuous_features = [
    'satisfaction_level', 'last_evaluation', 'number_project',
    'average_montly_hours', 'time_spend_company'
]
categorical_features = [
    'Work_accident', 'promotion_last_5years', 'sales', 'salary'
]
target = 'left'
full_dec_tree = ID3_for_continuous(train_df, train_df, categorical_features,
                                   continuous_features, target, 1)
# inorder(full_dec_tree)

# %%
predict = test_continuous(X_test, full_dec_tree)
evaluate_result(y_test, predict)
# Out:
# tn = 1668, fp = 36, fn = 24, tp = 496
# f1_score	 :  0.9626489674723562
# precision_score	 :  0.9590732149522743
# recall_score	 :  0.9663596966413868
# accuracy_score	 :  0.9730215827338129
# (0.9626489674723562,
#  0.9590732149522743,
#  0.9663596966413868,
#  0.9730215827338129)

# %% [markdown]
# ## Results:
# - tn = 1668, fp = 36, fn = 24, tp = 496
# - f1_score	 :  0.9626489674723562
# - precision_score	 :  0.9590732149522743
# - recall_score	 :  0.9663596966413868
# - accuracy_score	 :  0.9730215827338129

# %% [markdown]
# # Part 3: Effectiveness of Misclassification, entropy and gini function:
# I constructed 3 trees with each of the mentioned fucntions, They are evaluated over the test data. The results are stored in a dataframe.
# <br>
# I've also done the comparison with scikit learn here itself. The results are quite similar.

# %%
functions = [find_entropy, find_misclassification, find_gini_index]
columns = ['metrics', 'f1-score', 'precision', 'recall', 'accuracy']
result_df = pd.DataFrame(index=np.arange(0, 3), columns=columns)
for i, function in enumerate(functions):
    dec_tree = ID3_for_continuous(
        train_df,
        train_df,
        categorical_features,
        continuous_features,
        target,
        error_function=function)
    predict = test_continuous(X_test, dec_tree)
    f1, ps, rs, acs = evaluate_result(y_test, predict)
    result_df.loc[i] = [function.__name__, f1, ps, rs, acs]
# Out:
# tn = 1672, fp = 50, fn = 25, tp = 522
# f1_score	 :  0.9555198163236982
# precision_score	 :  0.9489277663997758
# recall_score	 :  0.9626300781158765
# accuracy_score	 :  0.9669457910973998
# tn = 1624, fp = 98, fn = 151, tp = 396
# f1_score	 :  0.844801513689379
# precision_score	 :  0.8582745053315847
# recall_score	 :  0.8335191212972459
# accuracy_score	 :  0.8902600264433671
# tn = 1677, fp = 45, fn = 25, tp = 522
# f1_score	 :  0.9583597249953857
# precision_score	 :  0.9529731594948986
# recall_score	 :  0.9640818783481645
# accuracy_score	 :  0.9691494050242397

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini",
                               max_depth=7)
clf_gini.fit(X_train, y_train)
print(X_test.shape, X_train.shape)
y_pred = clf_gini.predict(X_test)
evaluate_result(y_test, y_pred)
# Out:
# (2269, 9) (8969, 9)
# tn = 1712, fp = 10, fn = 41, tp = 506
# f1_score	 :  0.9686731593088651
# precision_score	 :  0.9786158390710056
# recall_score	 :  0.9596192514549852
# accuracy_score	 :  0.9775231379462318
# (0.9686731593088651,
#  0.9786158390710056,
#  0.9596192514549852,
#  0.9775231379462318)

# %%
clf_entropy = DecisionTreeClassifier(criterion = "entropy",
                               max_depth=7)
clf_entropy.fit(X_train, y_train)
print(X_test.shape, X_train.shape)
y_pred = clf_entropy.predict(X_test)
evaluate_result(y_test, y_pred)
# Out:
# (2269, 9) (8969, 9)
# tn = 1705, fp = 17, fn = 42, tp = 505
# f1_score	 :  0.9639002243848427
# precision_score	 :  0.9716958683413492
# recall_score	 :  0.9566726543473322
# accuracy_score	 :  0.9739973556632878
# (0.9639002243848427,
#  0.9716958683413492,
#  0.9566726543473322,
#  0.9739973556632878)

# %%
print(result_df.head())
# Out:
#                   metrics  f1-score precision    recall  accuracy
# 0            find_entropy   0.95552  0.948928   0.96263  0.966946
# 1  find_misclassification  0.844802  0.858275  0.833519   0.89026
# 2         find_gini_index   0.95836  0.952973  0.964082  0.969149

# %% [markdown]
# # Part 4: Visualize data on 2D Plot
# I've alredy did this while studying the data. However as mentioned in the assignment the graph should be among the variables with visible decision boundaries.<br>
# I've found satisfaction level, last evaluation and average monthly hours are resulting in pretty nice decision boundaries

# %%
print(df.head())
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.10             0.90               7                   286
# 1                0.89             0.93               4                   249
# 2                0.38             0.50               2                   132
# 3                0.95             0.71               4                   151
# 4                0.84             0.84               5                   163
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   4              0     1                      0      0
# 1                   3              0     0                      0      0
# 2                   3              0     1                      0      1
# 3                   4              0     0                      0      0
# 4                   3              0     0                      0      2
#
#    salary
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0

# %%
visual_df = df[['satisfaction_level', 'last_evaluation', 'average_montly_hours', 'left']]
sns.pairplot(visual_df, hue='left')

# %% [markdown]
# # Part 5: Graph between depth, number of nodes and training error and validation error.
# I created trees with restricted depths and calculated the training and validation error over.

# %%
training_accuracy = []
depth = []
validation_accuracy = []
no_of_node = []
for i in range(1,16):
    dec_tree = ID3_for_continuous(
        train_df,
        train_df,
        categorical_features,
        continuous_features,
        target,
        max_depth=i)
    depth.append(i)
    no_of_node.append(inorder(dec_tree))
    predict = test_continuous(X_test, dec_tree)
    validation_accuracy.append(evaluate_result(y_test, predict)[-1])
    predict = test_continuous(X_train, dec_tree)
    training_accuracy.append(evaluate_result(y_train, predict)[-1])
# Out:
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.0
# 	value = 0.46, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5876, 1.0: 616}, split_val = 0.0
# tn = 1450, fp = 272, fn = 161, tp = 386
# f1_score	 :  0.7553754545579039
# precision_score	 :  0.7433441065320301
# recall_score	 :  0.7738557053891248
# accuracy_score	 :  0.8091670339356545
# tn = 5876, fp = 965, fn = 616, tp = 1512
# f1_score	 :  0.7690497799904281
# precision_score	 :  0.7577649060201668
# recall_score	 :  0.784732533716985
# accuracy_score	 :  0.8237261679116958
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = satisfaction_level, info_gain = 0.18576619361644808,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.11
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 548}, split_val = 0.0
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 965, 1.0: 964}, split_val = 0.0
# 	value = 0.46, name = time_spend_company, info_gain = 0.1777616511027702,  leaf = False, target = None, class_count = {0.0: 5876, 1.0: 616}, split_val = 4.0
# 		value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5246, 1.0: 85}, split_val = 0.0
# 		value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 630, 1.0: 531}, split_val = 0.0
# tn = 1722, fp = 0, fn = 421, tp = 126
# f1_score	 :  0.6327582660712878
# precision_score	 :  0.9017732151189921
# recall_score	 :  0.6151736745886655
# accuracy_score	 :  0.8144557073600706
# tn = 6841, fp = 0, fn = 1580, tp = 548
# f1_score	 :  0.6530207110913141
# precision_score	 :  0.9061869136682104
# recall_score	 :  0.6287593984962406
# accuracy_score	 :  0.8238376630616568
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = satisfaction_level, info_gain = 0.18576619361644808,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.11
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 548}, split_val = 0.0
# 		value = 0.11, name = number_project, info_gain = 0.5614976405750883,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 964}, split_val = 2.0
# 			value = 2.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 113, 1.0: 900}, split_val = 0.0
# 			value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 852, 1.0: 64}, split_val = 0.0
# 	value = 0.46, name = time_spend_company, info_gain = 0.1777616511027702,  leaf = False, target = None, class_count = {0.0: 5876, 1.0: 616}, split_val = 4.0
# 		value = 4.0, name = average_montly_hours, info_gain = 0.010211829785241003,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 85}, split_val = 287.0
# 			value = 287.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5246, 1.0: 76}, split_val = 0.0
# 			value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 		value = 4.0, name = last_evaluation, info_gain = 0.3553140549910201,  leaf = False, target = None, class_count = {0.0: 630, 1.0: 531}, split_val = 0.8
# 			value = 0.8, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 426, 1.0: 22}, split_val = 0.0
# 			value = 0.8, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 204, 1.0: 509}, split_val = 0.0
# tn = 1612, fp = 110, fn = 38, tp = 509
# f1_score	 :  0.9145897299727958
# precision_score	 :  0.8996318597934106
# recall_score	 :  0.9333254771565735
# accuracy_score	 :  0.9347730277655355
# tn = 6524, fp = 317, fn = 162, tp = 1966
# f1_score	 :  0.9279985919325693
# precision_score	 :  0.9184589395090637
# recall_score	 :  0.9387669629049967
# accuracy_score	 :  0.9465938231686921
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = satisfaction_level, info_gain = 0.18576619361644808,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.11
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 548}, split_val = 0.0
# 		value = 0.11, name = number_project, info_gain = 0.5614976405750883,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 964}, split_val = 2.0
# 			value = 2.0, name = last_evaluation, info_gain = 0.20844499770983993,  leaf = False, target = None, class_count = {0.0: 113, 1.0: 900}, split_val = 0.57
# 				value = 0.57, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 49, 1.0: 896}, split_val = 0.0
# 				value = 0.57, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 64, 1.0: 4}, split_val = 0.0
# 			value = 2.0, name = number_project, info_gain = 0.03869855511057546,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 64}, split_val = 6.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 852, 1.0: 55}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 	value = 0.46, name = time_spend_company, info_gain = 0.1777616511027702,  leaf = False, target = None, class_count = {0.0: 5876, 1.0: 616}, split_val = 4.0
# 		value = 4.0, name = average_montly_hours, info_gain = 0.010211829785241003,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 85}, split_val = 287.0
# 			value = 287.0, name = number_project, info_gain = 0.006594153507468864,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 76}, split_val = 5.0
# 				value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5163, 1.0: 61}, split_val = 0.0
# 				value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 83, 1.0: 15}, split_val = 0.0
# 			value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 		value = 4.0, name = last_evaluation, info_gain = 0.3553140549910201,  leaf = False, target = None, class_count = {0.0: 630, 1.0: 531}, split_val = 0.8
# 			value = 0.8, name = sales, info_gain = 0.05936498854042482,  leaf = False, target = None, class_count = {0.0: 426, 1.0: 22}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 145}, split_val = 0.0
# 				value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 16, 1.0: 1}, split_val = 0.0
# 				value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 51, 1.0: 9}, split_val = 0.0
# 				value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 52}, split_val = 0.0
# 				value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 46, 1.0: 2}, split_val = 0.0
# 				value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 24}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 20, 1.0: 2}, split_val = 0.0
# 				value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18, 1.0: 1}, split_val = 0.0
# 				value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 41, 1.0: 4}, split_val = 0.0
# 				value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 13, 1.0: 3}, split_val = 0.0
# 			value = 0.8, name = time_spend_company, info_gain = 0.309705918899841,  leaf = False, target = None, class_count = {0.0: 204, 1.0: 509}, split_val = 6.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 101, 1.0: 509}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 103}, split_val = 0.0
# tn = 1665, fp = 57, fn = 38, tp = 509
# f1_score	 :  0.9434539385234881
# precision_score	 :  0.938489860960392
# recall_score	 :  0.9487145596188269
# accuracy_score	 :  0.9581313353900397
# tn = 6691, fp = 150, fn = 157, tp = 1971
# f1_score	 :  0.9526604696629619
# precision_score	 :  0.9531761201403852
# recall_score	 :  0.9521475927979575
# accuracy_score	 :  0.9657709889619801
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = satisfaction_level, info_gain = 0.18576619361644808,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.11
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 548}, split_val = 0.0
# 		value = 0.11, name = number_project, info_gain = 0.5614976405750883,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 964}, split_val = 2.0
# 			value = 2.0, name = last_evaluation, info_gain = 0.20844499770983993,  leaf = False, target = None, class_count = {0.0: 113, 1.0: 900}, split_val = 0.57
# 				value = 0.57, name = average_montly_hours, info_gain = 0.09649287888551122,  leaf = False, target = None, class_count = {0.0: 49, 1.0: 896}, split_val = 161.0
# 					value = 161.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 28, 1.0: 895}, split_val = 0.0
# 					value = 161.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 21, 1.0: 1}, split_val = 0.0
# 				value = 0.57, name = average_montly_hours, info_gain = 0.09275460347801179,  leaf = False, target = None, class_count = {0.0: 64, 1.0: 4}, split_val = 278.0
# 					value = 278.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 63, 1.0: 2}, split_val = 0.0
# 					value = 278.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 1, 1.0: 2}, split_val = 0.0
# 			value = 2.0, name = number_project, info_gain = 0.03869855511057546,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 64}, split_val = 6.0
# 				value = 6.0, name = average_montly_hours, info_gain = 0.018055986318461725,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 55}, split_val = 287.0
# 					value = 287.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 852, 1.0: 51}, split_val = 0.0
# 					value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 4}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 	value = 0.46, name = time_spend_company, info_gain = 0.1777616511027702,  leaf = False, target = None, class_count = {0.0: 5876, 1.0: 616}, split_val = 4.0
# 		value = 4.0, name = average_montly_hours, info_gain = 0.010211829785241003,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 85}, split_val = 287.0
# 			value = 287.0, name = number_project, info_gain = 0.006594153507468864,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 76}, split_val = 5.0
# 				value = 5.0, name = time_spend_company, info_gain = 0.004634581150898501,  leaf = False, target = None, class_count = {0.0: 5163, 1.0: 61}, split_val = 3.0
# 					value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4411, 1.0: 33}, split_val = 0.0
# 					value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 752, 1.0: 28}, split_val = 0.0
# 				value = 5.0, name = sales, info_gain = 0.09501839277647228,  leaf = False, target = None, class_count = {0.0: 83, 1.0: 15}, split_val = 0.0
# 					value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 29, 1.0: 3}, split_val = 0.0
# 					value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 					value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 15, 1.0: 3}, split_val = 0.0
# 					value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2, 1.0: 2}, split_val = 0.0
# 					value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 6, 1.0: 4}, split_val = 0.0
# 					value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 8}, split_val = 0.0
# 					value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5, 1.0: 1}, split_val = 0.0
# 					value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 					value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 9, 1.0: 2}, split_val = 0.0
# 					value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 			value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 		value = 4.0, name = last_evaluation, info_gain = 0.3553140549910201,  leaf = False, target = None, class_count = {0.0: 630, 1.0: 531}, split_val = 0.8
# 			value = 0.8, name = sales, info_gain = 0.05936498854042482,  leaf = False, target = None, class_count = {0.0: 426, 1.0: 22}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 145}, split_val = 0.0
# 				value = 1.0, name = satisfaction_level, info_gain = 0.20510990007386878,  leaf = False, target = None, class_count = {0.0: 16, 1.0: 1}, split_val = 0.85
# 					value = 0.85, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 15}, split_val = 0.0
# 					value = 0.85, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1, 1.0: 1}, split_val = 0.0
# 				value = 2.0, name = salary, info_gain = 0.21038734862365016,  leaf = False, target = None, class_count = {0.0: 51, 1.0: 9}, split_val = 0.0
# 					value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 23, 1.0: 1}, split_val = 0.0
# 					value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 27, 1.0: 3}, split_val = 0.0
# 					value = 2.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 1, 1.0: 5}, split_val = 0.0
# 				value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 52}, split_val = 0.0
# 				value = 4.0, name = average_montly_hours, info_gain = 0.07284807203540253,  leaf = False, target = None, class_count = {0.0: 46, 1.0: 2}, split_val = 166.0
# 					value = 166.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 13, 1.0: 2}, split_val = 0.0
# 					value = 166.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 33}, split_val = 0.0
# 				value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 24}, split_val = 0.0
# 				value = 6.0, name = last_evaluation, info_gain = 0.2576788051033316,  leaf = False, target = None, class_count = {0.0: 20, 1.0: 2}, split_val = 0.68
# 					value = 0.68, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 					value = 0.68, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2, 1.0: 2}, split_val = 0.0
# 				value = 7.0, name = last_evaluation, info_gain = 0.2974722489192896,  leaf = False, target = None, class_count = {0.0: 18, 1.0: 1}, split_val = 0.75
# 					value = 0.75, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 					value = 0.75, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 				value = 8.0, name = average_montly_hours, info_gain = 0.17342233072544783,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 4}, split_val = 265.0
# 					value = 265.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 41, 1.0: 2}, split_val = 0.0
# 					value = 265.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 				value = 9.0, name = average_montly_hours, info_gain = 0.4933927290103627,  leaf = False, target = None, class_count = {0.0: 13, 1.0: 3}, split_val = 275.0
# 					value = 275.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 					value = 275.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 1, 1.0: 3}, split_val = 0.0
# 			value = 0.8, name = time_spend_company, info_gain = 0.309705918899841,  leaf = False, target = None, class_count = {0.0: 204, 1.0: 509}, split_val = 6.0
# 				value = 6.0, name = average_montly_hours, info_gain = 0.22232815870479566,  leaf = False, target = None, class_count = {0.0: 101, 1.0: 509}, split_val = 210.0
# 					value = 210.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 59, 1.0: 12}, split_val = 0.0
# 					value = 210.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 42, 1.0: 497}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 103}, split_val = 0.0
# tn = 1695, fp = 27, fn = 38, tp = 509
# f1_score	 :  0.960584109370845
# precision_score	 :  0.9638497859806565
# recall_score	 :  0.957425361012555
# accuracy_score	 :  0.9713530189510797
# tn = 6768, fp = 73, fn = 153, tp = 1975
# f1_score	 :  0.9647295971860992
# precision_score	 :  0.9711244183802016
# recall_score	 :  0.9587152746102943
# accuracy_score	 :  0.9748020961088193
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = satisfaction_level, info_gain = 0.18576619361644808,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.11
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 548}, split_val = 0.0
# 		value = 0.11, name = number_project, info_gain = 0.5614976405750883,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 964}, split_val = 2.0
# 			value = 2.0, name = last_evaluation, info_gain = 0.20844499770983993,  leaf = False, target = None, class_count = {0.0: 113, 1.0: 900}, split_val = 0.57
# 				value = 0.57, name = average_montly_hours, info_gain = 0.09649287888551122,  leaf = False, target = None, class_count = {0.0: 49, 1.0: 896}, split_val = 161.0
# 					value = 161.0, name = average_montly_hours, info_gain = 0.10314143190959699,  leaf = False, target = None, class_count = {0.0: 28, 1.0: 895}, split_val = 125.0
# 						value = 125.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 17}, split_val = 0.0
# 						value = 125.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 11, 1.0: 895}, split_val = 0.0
# 					value = 161.0, name = average_montly_hours, info_gain = 0.14154282861377748,  leaf = False, target = None, class_count = {0.0: 21, 1.0: 1}, split_val = 232.0
# 						value = 232.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 19}, split_val = 0.0
# 						value = 232.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2, 1.0: 1}, split_val = 0.0
# 				value = 0.57, name = average_montly_hours, info_gain = 0.09275460347801179,  leaf = False, target = None, class_count = {0.0: 64, 1.0: 4}, split_val = 278.0
# 					value = 278.0, name = time_spend_company, info_gain = 0.043550660173815176,  leaf = False, target = None, class_count = {0.0: 63, 1.0: 2}, split_val = 3.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 40}, split_val = 0.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 23, 1.0: 2}, split_val = 0.0
# 					value = 278.0, name = average_montly_hours, info_gain = 0.9182958340544896,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 2}, split_val = 282.0
# 						value = 282.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 						value = 282.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 2.0, name = number_project, info_gain = 0.03869855511057546,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 64}, split_val = 6.0
# 				value = 6.0, name = average_montly_hours, info_gain = 0.018055986318461725,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 55}, split_val = 287.0
# 					value = 287.0, name = sales, info_gain = 0.01568116801972813,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 51}, split_val = 0.0
# 						value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 252, 1.0: 16}, split_val = 0.0
# 						value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54, 1.0: 7}, split_val = 0.0
# 						value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 142, 1.0: 11}, split_val = 0.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 34, 1.0: 2}, split_val = 0.0
# 						value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 53, 1.0: 1}, split_val = 0.0
# 						value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 58, 1.0: 1}, split_val = 0.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54}, split_val = 0.0
# 						value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 61, 1.0: 3}, split_val = 0.0
# 						value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 111, 1.0: 10}, split_val = 0.0
# 						value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 33}, split_val = 0.0
# 					value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 4}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 	value = 0.46, name = time_spend_company, info_gain = 0.1777616511027702,  leaf = False, target = None, class_count = {0.0: 5876, 1.0: 616}, split_val = 4.0
# 		value = 4.0, name = average_montly_hours, info_gain = 0.010211829785241003,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 85}, split_val = 287.0
# 			value = 287.0, name = number_project, info_gain = 0.006594153507468864,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 76}, split_val = 5.0
# 				value = 5.0, name = time_spend_company, info_gain = 0.004634581150898501,  leaf = False, target = None, class_count = {0.0: 5163, 1.0: 61}, split_val = 3.0
# 					value = 3.0, name = number_project, info_gain = 0.003930005074884238,  leaf = False, target = None, class_count = {0.0: 4411, 1.0: 33}, split_val = 2.0
# 						value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 239, 1.0: 11}, split_val = 0.0
# 						value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4172, 1.0: 22}, split_val = 0.0
# 					value = 3.0, name = sales, info_gain = 0.027633156695081762,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 28}, split_val = 0.0
# 						value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 209, 1.0: 7}, split_val = 0.0
# 						value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 42}, split_val = 0.0
# 						value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 131, 1.0: 10}, split_val = 0.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 26}, split_val = 0.0
# 						value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 59}, split_val = 0.0
# 						value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 48}, split_val = 0.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 45, 1.0: 1}, split_val = 0.0
# 						value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 50}, split_val = 0.0
# 						value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 110, 1.0: 4}, split_val = 0.0
# 						value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 32, 1.0: 6}, split_val = 0.0
# 				value = 5.0, name = sales, info_gain = 0.09501839277647228,  leaf = False, target = None, class_count = {0.0: 83, 1.0: 15}, split_val = 0.0
# 					value = 0.0, name = last_evaluation, info_gain = 0.2613644887230294,  leaf = False, target = None, class_count = {0.0: 29, 1.0: 3}, split_val = 0.89
# 						value = 0.89, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 26}, split_val = 0.0
# 						value = 0.89, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3, 1.0: 3}, split_val = 0.0
# 					value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 					value = 2.0, name = number_project, info_gain = 0.3502090290998973,  leaf = False, target = None, class_count = {0.0: 15, 1.0: 3}, split_val = 6.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 15, 1.0: 1}, split_val = 0.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 					value = 3.0, name = average_montly_hours, info_gain = 0.31127812445913283,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 2}, split_val = 156.0
# 						value = 156.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 						value = 156.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2, 1.0: 1}, split_val = 0.0
# 					value = 4.0, name = average_montly_hours, info_gain = 0.6099865470109874,  leaf = False, target = None, class_count = {0.0: 6, 1.0: 4}, split_val = 161.0
# 						value = 161.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 1, 1.0: 4}, split_val = 0.0
# 						value = 161.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5}, split_val = 0.0
# 					value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 8}, split_val = 0.0
# 					value = 6.0, name = last_evaluation, info_gain = 0.6500224216483541,  leaf = False, target = None, class_count = {0.0: 5, 1.0: 1}, split_val = 0.89
# 						value = 0.89, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5}, split_val = 0.0
# 						value = 0.89, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 					value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 					value = 8.0, name = average_montly_hours, info_gain = 0.320402072002678,  leaf = False, target = None, class_count = {0.0: 9, 1.0: 2}, split_val = 136.0
# 						value = 136.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2, 1.0: 2}, split_val = 0.0
# 						value = 136.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 7}, split_val = 0.0
# 					value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 			value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 		value = 4.0, name = last_evaluation, info_gain = 0.3553140549910201,  leaf = False, target = None, class_count = {0.0: 630, 1.0: 531}, split_val = 0.8
# 			value = 0.8, name = sales, info_gain = 0.05936498854042482,  leaf = False, target = None, class_count = {0.0: 426, 1.0: 22}, split_val = 0.0
# 				value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 145}, split_val = 0.0
# 				value = 1.0, name = satisfaction_level, info_gain = 0.20510990007386878,  leaf = False, target = None, class_count = {0.0: 16, 1.0: 1}, split_val = 0.85
# 					value = 0.85, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 15}, split_val = 0.0
# 					value = 0.85, name = average_montly_hours, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 1}, split_val = 135.0
# 						value = 135.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 						value = 135.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 				value = 2.0, name = salary, info_gain = 0.21038734862365016,  leaf = False, target = None, class_count = {0.0: 51, 1.0: 9}, split_val = 0.0
# 					value = 0.0, name = average_montly_hours, info_gain = 0.06869414509998664,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 1}, split_val = 153.0
# 						value = 153.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 7, 1.0: 1}, split_val = 0.0
# 						value = 153.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 16}, split_val = 0.0
# 					value = 1.0, name = satisfaction_level, info_gain = 0.2689955935892812,  leaf = False, target = None, class_count = {0.0: 27, 1.0: 3}, split_val = 0.57
# 						value = 0.57, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3, 1.0: 3}, split_val = 0.0
# 						value = 0.57, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 24}, split_val = 0.0
# 					value = 2.0, name = satisfaction_level, info_gain = 0.6500224216483541,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 5}, split_val = 0.8
# 						value = 0.8, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 5}, split_val = 0.0
# 						value = 0.8, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 				value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 52}, split_val = 0.0
# 				value = 4.0, name = average_montly_hours, info_gain = 0.07284807203540253,  leaf = False, target = None, class_count = {0.0: 46, 1.0: 2}, split_val = 166.0
# 					value = 166.0, name = average_montly_hours, info_gain = 0.22002600168808806,  leaf = False, target = None, class_count = {0.0: 13, 1.0: 2}, split_val = 154.0
# 						value = 154.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 13, 1.0: 1}, split_val = 0.0
# 						value = 154.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 					value = 166.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 33}, split_val = 0.0
# 				value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 24}, split_val = 0.0
# 				value = 6.0, name = last_evaluation, info_gain = 0.2576788051033316,  leaf = False, target = None, class_count = {0.0: 20, 1.0: 2}, split_val = 0.68
# 					value = 0.68, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 					value = 0.68, name = average_montly_hours, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 2}, split_val = 211.0
# 						value = 211.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 211.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 				value = 7.0, name = last_evaluation, info_gain = 0.2974722489192896,  leaf = False, target = None, class_count = {0.0: 18, 1.0: 1}, split_val = 0.75
# 					value = 0.75, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 					value = 0.75, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 				value = 8.0, name = average_montly_hours, info_gain = 0.17342233072544783,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 4}, split_val = 265.0
# 					value = 265.0, name = last_evaluation, info_gain = 0.07875193866735336,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 2}, split_val = 0.62
# 						value = 0.62, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 29}, split_val = 0.0
# 						value = 0.62, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12, 1.0: 2}, split_val = 0.0
# 					value = 265.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 				value = 9.0, name = average_montly_hours, info_gain = 0.4933927290103627,  leaf = False, target = None, class_count = {0.0: 13, 1.0: 3}, split_val = 275.0
# 					value = 275.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 					value = 275.0, name = average_montly_hours, info_gain = 0.8112781244591328,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 3}, split_val = 281.0
# 						value = 281.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 3}, split_val = 0.0
# 						value = 281.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 0.8, name = time_spend_company, info_gain = 0.309705918899841,  leaf = False, target = None, class_count = {0.0: 204, 1.0: 509}, split_val = 6.0
# 				value = 6.0, name = average_montly_hours, info_gain = 0.22232815870479566,  leaf = False, target = None, class_count = {0.0: 101, 1.0: 509}, split_val = 210.0
# 					value = 210.0, name = sales, info_gain = 0.16310351959807473,  leaf = False, target = None, class_count = {0.0: 59, 1.0: 12}, split_val = 0.0
# 						value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 14, 1.0: 4}, split_val = 0.0
# 						value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 						value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 14, 1.0: 1}, split_val = 0.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 8}, split_val = 0.0
# 						value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5, 1.0: 1}, split_val = 0.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 6, 1.0: 6}, split_val = 0.0
# 						value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 					value = 210.0, name = satisfaction_level, info_gain = 0.11470570000329444,  leaf = False, target = None, class_count = {0.0: 42, 1.0: 497}, split_val = 0.71
# 						value = 0.71, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 19, 1.0: 4}, split_val = 0.0
# 						value = 0.71, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 23, 1.0: 493}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 103}, split_val = 0.0
# tn = 1701, fp = 21, fn = 41, tp = 506
# f1_score	 :  0.9621867487237712
# precision_score	 :  0.9683078186646682
# recall_score	 :  0.9564252909439515
# accuracy_score	 :  0.9726751873071838
# tn = 6806, fp = 35, fn = 145, tp = 1983
# f1_score	 :  0.9717668079148214
# precision_score	 :  0.9808978936371677
# recall_score	 :  0.9633723455876939
# accuracy_score	 :  0.9799308730070242
# value = None, name = satisfaction_level, info_gain = 0.19649557315938493,  leaf = False, target = None, class_count = {0: 6841, 1: 2128}, split_val = 0.46
# 	value = 0.46, name = satisfaction_level, info_gain = 0.18576619361644808,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 1512}, split_val = 0.11
# 		value = 0.11, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 548}, split_val = 0.0
# 		value = 0.11, name = number_project, info_gain = 0.5614976405750883,  leaf = False, target = None, class_count = {0.0: 965, 1.0: 964}, split_val = 2.0
# 			value = 2.0, name = last_evaluation, info_gain = 0.20844499770983993,  leaf = False, target = None, class_count = {0.0: 113, 1.0: 900}, split_val = 0.57
# 				value = 0.57, name = average_montly_hours, info_gain = 0.09649287888551122,  leaf = False, target = None, class_count = {0.0: 49, 1.0: 896}, split_val = 161.0
# 					value = 161.0, name = average_montly_hours, info_gain = 0.10314143190959699,  leaf = False, target = None, class_count = {0.0: 28, 1.0: 895}, split_val = 125.0
# 						value = 125.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 17}, split_val = 0.0
# 						value = 125.0, name = last_evaluation, info_gain = 0.029414158890649245,  leaf = False, target = None, class_count = {0.0: 11, 1.0: 895}, split_val = 0.44
# 							value = 0.44, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 							value = 0.44, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {0.0: 7, 1.0: 895}, split_val = 0.0
# 					value = 161.0, name = average_montly_hours, info_gain = 0.14154282861377748,  leaf = False, target = None, class_count = {0.0: 21, 1.0: 1}, split_val = 232.0
# 						value = 232.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 19}, split_val = 0.0
# 						value = 232.0, name = average_montly_hours, info_gain = 0.9182958340544896,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 1}, split_val = 248.0
# 							value = 248.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 							value = 248.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 				value = 0.57, name = average_montly_hours, info_gain = 0.09275460347801179,  leaf = False, target = None, class_count = {0.0: 64, 1.0: 4}, split_val = 278.0
# 					value = 278.0, name = time_spend_company, info_gain = 0.043550660173815176,  leaf = False, target = None, class_count = {0.0: 63, 1.0: 2}, split_val = 3.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 40}, split_val = 0.0
# 						value = 3.0, name = sales, info_gain = 0.11340795224732786,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 2}, split_val = 0.0
# 							value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4, 1.0: 1}, split_val = 0.0
# 							value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4, 1.0: 1}, split_val = 0.0
# 							value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 							value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 							value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 							value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 							value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 							value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 					value = 278.0, name = average_montly_hours, info_gain = 0.9182958340544896,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 2}, split_val = 282.0
# 						value = 282.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 						value = 282.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 2.0, name = number_project, info_gain = 0.03869855511057546,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 64}, split_val = 6.0
# 				value = 6.0, name = average_montly_hours, info_gain = 0.018055986318461725,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 55}, split_val = 287.0
# 					value = 287.0, name = sales, info_gain = 0.01568116801972813,  leaf = False, target = None, class_count = {0.0: 852, 1.0: 51}, split_val = 0.0
# 						value = 0.0, name = satisfaction_level, info_gain = 0.028112697651597518,  leaf = False, target = None, class_count = {0.0: 252, 1.0: 16}, split_val = 0.3
# 							value = 0.3, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 166, 1.0: 4}, split_val = 0.0
# 							value = 0.3, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 86, 1.0: 12}, split_val = 0.0
# 						value = 1.0, name = last_evaluation, info_gain = 0.10913432293477066,  leaf = False, target = None, class_count = {0.0: 54, 1.0: 7}, split_val = 0.95
# 							value = 0.95, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54, 1.0: 5}, split_val = 0.0
# 							value = 0.95, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 						value = 2.0, name = average_montly_hours, info_gain = 0.02184754898255259,  leaf = False, target = None, class_count = {0.0: 142, 1.0: 11}, split_val = 237.0
# 							value = 237.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 114, 1.0: 11}, split_val = 0.0
# 							value = 237.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 28}, split_val = 0.0
# 						value = 3.0, name = satisfaction_level, info_gain = 0.17468917992051008,  leaf = False, target = None, class_count = {0.0: 34, 1.0: 2}, split_val = 0.38
# 							value = 0.38, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 31}, split_val = 0.0
# 							value = 0.38, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3, 1.0: 2}, split_val = 0.0
# 						value = 4.0, name = satisfaction_level, info_gain = 0.05251158295149948,  leaf = False, target = None, class_count = {0.0: 53, 1.0: 1}, split_val = 0.14
# 							value = 0.14, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 7, 1.0: 1}, split_val = 0.0
# 							value = 0.14, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 46}, split_val = 0.0
# 						value = 5.0, name = satisfaction_level, info_gain = 0.06276952068665485,  leaf = False, target = None, class_count = {0.0: 58, 1.0: 1}, split_val = 0.42
# 							value = 0.42, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54}, split_val = 0.0
# 							value = 0.42, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4, 1.0: 1}, split_val = 0.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 54}, split_val = 0.0
# 						value = 7.0, name = last_evaluation, info_gain = 0.1575772070914105,  leaf = False, target = None, class_count = {0.0: 61, 1.0: 3}, split_val = 0.99
# 							value = 0.99, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 61, 1.0: 1}, split_val = 0.0
# 							value = 0.99, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 						value = 8.0, name = number_project, info_gain = 0.14049123514353995,  leaf = False, target = None, class_count = {0.0: 111, 1.0: 10}, split_val = 5.0
# 							value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 93, 1.0: 1}, split_val = 0.0
# 							value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18, 1.0: 9}, split_val = 0.0
# 						value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 33}, split_val = 0.0
# 					value = 287.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 4}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 9}, split_val = 0.0
# 	value = 0.46, name = time_spend_company, info_gain = 0.1777616511027702,  leaf = False, target = None, class_count = {0.0: 5876, 1.0: 616}, split_val = 4.0
# 		value = 4.0, name = average_montly_hours, info_gain = 0.010211829785241003,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 85}, split_val = 287.0
# 			value = 287.0, name = number_project, info_gain = 0.006594153507468864,  leaf = False, target = None, class_count = {0.0: 5246, 1.0: 76}, split_val = 5.0
# 				value = 5.0, name = time_spend_company, info_gain = 0.004634581150898501,  leaf = False, target = None, class_count = {0.0: 5163, 1.0: 61}, split_val = 3.0
# 					value = 3.0, name = number_project, info_gain = 0.003930005074884238,  leaf = False, target = None, class_count = {0.0: 4411, 1.0: 33}, split_val = 2.0
# 						value = 2.0, name = average_montly_hours, info_gain = 0.03938311621408069,  leaf = False, target = None, class_count = {0.0: 239, 1.0: 11}, split_val = 180.0
# 							value = 180.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 113}, split_val = 0.0
# 							value = 180.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 126, 1.0: 11}, split_val = 0.0
# 						value = 2.0, name = sales, info_gain = 0.0025824225697817643,  leaf = False, target = None, class_count = {0.0: 4172, 1.0: 22}, split_val = 0.0
# 							value = 0.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1108, 1.0: 11}, split_val = 0.0
# 							value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 195, 1.0: 1}, split_val = 0.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 753, 1.0: 2}, split_val = 0.0
# 							value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 158, 1.0: 2}, split_val = 0.0
# 							value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 356}, split_val = 0.0
# 							value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 260}, split_val = 0.0
# 							value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 235}, split_val = 0.0
# 							value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 240, 1.0: 1}, split_val = 0.0
# 							value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 666, 1.0: 4}, split_val = 0.0
# 							value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 201, 1.0: 1}, split_val = 0.0
# 					value = 3.0, name = sales, info_gain = 0.027633156695081762,  leaf = False, target = None, class_count = {0.0: 752, 1.0: 28}, split_val = 0.0
# 						value = 0.0, name = last_evaluation, info_gain = 0.04337849647025985,  leaf = False, target = None, class_count = {0.0: 209, 1.0: 7}, split_val = 0.53
# 							value = 0.53, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 24, 1.0: 5}, split_val = 0.0
# 							value = 0.53, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 185, 1.0: 2}, split_val = 0.0
# 						value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 42}, split_val = 0.0
# ...
# 						value = 154.0, name = last_evaluation, info_gain = 0.37123232664087563,  leaf = False, target = None, class_count = {0.0: 13, 1.0: 1}, split_val = 0.73
# 							value = 0.73, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 13}, split_val = 0.0
# 							value = 0.73, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 						value = 154.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 					value = 166.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 33}, split_val = 0.0
# 				value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 24}, split_val = 0.0
# 				value = 6.0, name = last_evaluation, info_gain = 0.2576788051033316,  leaf = False, target = None, class_count = {0.0: 20, 1.0: 2}, split_val = 0.68
# 					value = 0.68, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 					value = 0.68, name = average_montly_hours, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 2}, split_val = 211.0
# 						value = 211.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 211.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 				value = 7.0, name = last_evaluation, info_gain = 0.2974722489192896,  leaf = False, target = None, class_count = {0.0: 18, 1.0: 1}, split_val = 0.75
# 					value = 0.75, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 18}, split_val = 0.0
# 					value = 0.75, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 				value = 8.0, name = average_montly_hours, info_gain = 0.17342233072544783,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 4}, split_val = 265.0
# 					value = 265.0, name = last_evaluation, info_gain = 0.07875193866735336,  leaf = False, target = None, class_count = {0.0: 41, 1.0: 2}, split_val = 0.62
# 						value = 0.62, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 29}, split_val = 0.0
# 						value = 0.62, name = last_evaluation, info_gain = 0.39489509985636545,  leaf = False, target = None, class_count = {0.0: 12, 1.0: 2}, split_val = 0.65
# 							value = 0.65, name = average_montly_hours, info_gain = 0.9182958340544896,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 2}, split_val = 156.0
# 								value = 156.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 								value = 156.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 							value = 0.65, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 11}, split_val = 0.0
# 					value = 265.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 				value = 9.0, name = average_montly_hours, info_gain = 0.4933927290103627,  leaf = False, target = None, class_count = {0.0: 13, 1.0: 3}, split_val = 275.0
# 					value = 275.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 					value = 275.0, name = average_montly_hours, info_gain = 0.8112781244591328,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 3}, split_val = 281.0
# 						value = 281.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 3}, split_val = 0.0
# 						value = 281.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 			value = 0.8, name = time_spend_company, info_gain = 0.309705918899841,  leaf = False, target = None, class_count = {0.0: 204, 1.0: 509}, split_val = 6.0
# 				value = 6.0, name = average_montly_hours, info_gain = 0.22232815870479566,  leaf = False, target = None, class_count = {0.0: 101, 1.0: 509}, split_val = 210.0
# 					value = 210.0, name = sales, info_gain = 0.16310351959807473,  leaf = False, target = None, class_count = {0.0: 59, 1.0: 12}, split_val = 0.0
# 						value = 0.0, name = last_evaluation, info_gain = 0.45810589515712374,  leaf = False, target = None, class_count = {0.0: 14, 1.0: 4}, split_val = 0.97
# 							value = 0.97, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 							value = 0.97, name = average_montly_hours, info_gain = 0.31668908831502096,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 4}, split_val = 158.0
# 								value = 158.0, name = salary, info_gain = 0.7219280948873623,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 4}, split_val = 0.0
# 									value = 0.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 4}, split_val = 0.0
# 									value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 								value = 158.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 						value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 						value = 2.0, name = number_project, info_gain = 0.22002600168808803,  leaf = False, target = None, class_count = {0.0: 14, 1.0: 1}, split_val = 2.0
# 							value = 2.0, name = average_montly_hours, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 1}, split_val = 101.0
# 								value = 101.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 								value = 101.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 13}, split_val = 0.0
# 						value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 8}, split_val = 0.0
# 						value = 5.0, name = number_project, info_gain = 0.6500224216483541,  leaf = False, target = None, class_count = {0.0: 5, 1.0: 1}, split_val = 2.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5}, split_val = 0.0
# 						value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 8.0, name = salary, info_gain = 0.6548575458269756,  leaf = False, target = None, class_count = {0.0: 6, 1.0: 6}, split_val = 0.0
# 							value = 0.0, name = average_montly_hours, info_gain = 0.5916727785823275,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 6}, split_val = 126.0
# 								value = 126.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 								value = 126.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 6}, split_val = 0.0
# 							value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 4}, split_val = 0.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 						value = 9.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 					value = 210.0, name = satisfaction_level, info_gain = 0.11470570000329444,  leaf = False, target = None, class_count = {0.0: 42, 1.0: 497}, split_val = 0.71
# 						value = 0.71, name = sales, info_gain = 0.262280083958103,  leaf = False, target = None, class_count = {0.0: 19, 1.0: 4}, split_val = 0.0
# 							value = 0.0, name = last_evaluation, info_gain = 0.29989639116789113,  leaf = False, target = None, class_count = {0.0: 8, 1.0: 3}, split_val = 0.89
# 								value = 0.89, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 5}, split_val = 0.0
# 								value = 0.89, name = satisfaction_level, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 3, 1.0: 3}, split_val = 0.66
# 									value = 0.66, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 3}, split_val = 0.0
# 									value = 0.66, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 							value = 1.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 							value = 2.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 							value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 							value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 							value = 5.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 							value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 							value = 7.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 							value = 8.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 						value = 0.71, name = number_project, info_gain = 0.11483721932197705,  leaf = False, target = None, class_count = {0.0: 23, 1.0: 493}, split_val = 3.0
# 							value = 3.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 12}, split_val = 0.0
# 							value = 3.0, name = number_project, info_gain = 0.034113631444738626,  leaf = False, target = None, class_count = {0.0: 11, 1.0: 493}, split_val = 5.0
# 								value = 5.0, name = last_evaluation, info_gain = 0.012719743330753028,  leaf = False, target = None, class_count = {0.0: 8, 1.0: 493}, split_val = 0.81
# 									value = 0.81, name = time_spend_company, info_gain = 0.863120568566631,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 5}, split_val = 5.0
# 										value = 5.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 5}, split_val = 0.0
# 										value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 2}, split_val = 0.0
# 									value = 0.81, name = sales, info_gain = 0.011142088009623019,  leaf = False, target = None, class_count = {0.0: 6, 1.0: 488}, split_val = 0.0
# 										value = 0.0, name = average_montly_hours, info_gain = 0.030416406697089886,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 137}, split_val = 223.0
# 											value = 223.0, name = number_project, info_gain = 0.5435644431995964,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 7}, split_val = 4.0
# 												value = 4.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 												value = 4.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 7}, split_val = 0.0
# 											value = 223.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 130}, split_val = 0.0
# 										value = 1.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 21}, split_val = 0.0
# 										value = 2.0, name = salary, info_gain = 0.027475958437193485,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 92}, split_val = 0.0
# 											value = 0.0, name = last_evaluation, info_gain = 0.07047275720535007,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 37}, split_val = 0.85
# 												value = 0.85, name = average_montly_hours, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 1}, split_val = 221.0
# 													value = 221.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 													value = 221.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 												value = 0.85, name = satisfaction_level, info_gain = 0.0360022824601777,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 36}, split_val = 0.85
# 													value = 0.85, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 22}, split_val = 0.0
# 													value = 0.85, name = satisfaction_level, info_gain = 0.22002600168808803,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 14}, split_val = 0.86
# 														value = 0.86, name = average_montly_hours, info_gain = 1.0,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 1}, split_val = 238.0
# 															value = 238.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 															value = 238.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 1}, split_val = 0.0
# 														value = 0.86, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 13}, split_val = 0.0
# 											value = 1.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 53}, split_val = 0.0
# 											value = 2.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 2}, split_val = 0.0
# 										value = 3.0, name = satisfaction_level, info_gain = 0.41381685030363374,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 11}, split_val = 0.88
# 											value = 0.88, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 11}, split_val = 0.0
# 											value = 0.88, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 										value = 4.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 36}, split_val = 0.0
# 										value = 5.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 37}, split_val = 0.0
# 										value = 6.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 26}, split_val = 0.0
# 										value = 7.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 22}, split_val = 0.0
# 										value = 8.0, name = satisfaction_level, info_gain = 0.06640778557221629,  leaf = False, target = None, class_count = {0.0: 2, 1.0: 87}, split_val = 0.91
# 											value = 0.91, name = average_montly_hours, info_gain = 0.045383679219916706,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 87}, split_val = 271.0
# 												value = 271.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 82}, split_val = 0.0
# 												value = 271.0, name = average_montly_hours, info_gain = 0.6500224216483541,  leaf = False, target = None, class_count = {0.0: 1, 1.0: 5}, split_val = 273.0
# 													value = 273.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 													value = 273.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 5}, split_val = 0.0
# 											value = 0.91, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 1}, split_val = 0.0
# 										value = 9.0, name = None, info_gain = 0,  leaf = True, target = 1.0, class_count = {1.0: 19}, split_val = 0.0
# 								value = 5.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 3}, split_val = 0.0
# 				value = 6.0, name = None, info_gain = 0,  leaf = True, target = 0.0, class_count = {0.0: 103}, split_val = 0.0
# tn = 1673, fp = 49, fn = 26, tp = 521
# f1_score	 :  0.9554662248574226
# precision_score	 :  0.949365984118625
# recall_score	 :  0.9620063613798844
# accuracy_score	 :  0.9669457910973998
# tn = 6841, fp = 0, fn = 3, tp = 2125
# f1_score	 :  0.9995376987217259
# precision_score	 :  0.9997808299240211
# recall_score	 :  0.9992951127819549
# accuracy_score	 :  0.9996655145501171

# %%
import matplotlib.pyplot as plt
plt.plot(depth, training_accuracy, label = 'training accuracy')
plt.plot(depth, validation_accuracy, label = 'validation_accuracy')
plt.show()

# %%
training_accuracy = [1.0-i for i in training_accuracy]
validation_accuracy = [1.0 -i for i in validation_accuracy]

# %%
plt.plot(no_of_node, training_accuracy, label = 'training accuracy')
plt.plot(no_of_node, validation_accuracy, label = 'validation_accuracy')
plt.show()

# %% [markdown]
# # Part 6: Handling missing values in Testing data
# Missing values in the test can be handled by traversing the tree. Suppose we are at node N and the split field is F. The value corresponding to F is missing in the test data. We will then traverse all the childrens of node N as we are doing for normal case. But instead of returning the class we will return the count/ no. of samples of each class from leafs. Then total count of each class is calculated at node N. The class with highest count is returned as predicted class for the corresponding test data/row.
# Other ways of handling missing data is to replace the missing values by mean of all the values of that column.
