# %%
import keras
from keras.models import Sequential
from keras.layers import Activation,LSTM,Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
# !wget https://www.kaggle.com/mousehead/songlyrics/downloads/songlyrics.zip/1
# Out:
# --2019-04-05 19:00:50--  https://www.kaggle.com/mousehead/songlyrics/downloads/songlyrics.zip/1
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /account/login?returnUrl=%2Fmousehead%2Fsonglyrics%2Fversion%2F1 [following]
# --2019-04-05 19:00:50--  https://www.kaggle.com/account/login?returnUrl=%2Fmousehead%2Fsonglyrics%2Fversion%2F1
# Reusing existing connection to www.kaggle.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘1’
#
# 1                       [ <=>                ]   7.93K  --.-KB/s    in 0.01s
#
# 2019-04-05 19:00:51 (753 KB/s) - ‘1’ saved [8124]

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
cd ..
# Out:
# /

# %%
ls gdrive
# Out:
# 'My Drive'/

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('../gdrive/My Drive/songdata.csv')['text']

# %%
df
# Out:
# 0        Look at her face, it's a wonderful face  \nAnd...
# 1        Take it easy with me, please  \nTouch me gentl...
# 2        I'll never know why I had to go  \nWhy I had t...
# 3        Making somebody happy is a question of give an...
# 4        Making somebody happy is a question of give an...
# 5        Well, you hoot and you holler and you make me ...
# 6        Down in the street they're all singing and sho...
# 7        Chiquitita, tell me what's wrong  \nYou're enc...
# 8        I was out with the morning sun  \nCouldn't sle...
# 9        I'm waitin' for you baby  \nI'm sitting all al...
# 10       Oh, my love it makes me sad.  \nWhy did things...
# 11       You can dance, you can jive, having the time o...
# 12       Changing, moving in a circle  \nI can see your...
# 13       You're so hot, teasing me  \nSo you're blue bu...
# 14       Agnetha We're not the stars of a Hollywood mov...
# 15       I can hear how you work, practising hard  \nPl...
# 16       They came flying from far away, now I'm under ...
# 17       Every good man needs a helping hand  \nso I tr...
# 18       Can you hear the drums Fernando?  \nI remember...
# 19       Puedes escuchar Fernando?  \nMe recuerda tiemp...
# 20       I'm down and I feel depressed  \nSitting here ...
# 21       Twinkle, Twinkle little star  \nHow I wonder w...
# 22       Half past twelve  \nAnd I'm watching the late ...
# 23       There's a gentleness to everything you do  \nA...
# 24       You say she's been mad at you  \nThen you say ...
# 25       When the autumn leaves are falling to the grou...
# 26       Agnetha, Frida Early this morning I drove in t...
# 27       No more champagne  \nAnd the fireworks are thr...
# 28       Benny I was a fighter, always looking for trou...
# 29       I have a very good friend  \nThe kind of girl ...
#                                ...
# 57620    LH cause 714 is the area  \nEverybody grab a f...
# 57621    Did you ever get the feeling that you were all...
# 57622    I'm up and I'm alright  \nPush on with all my ...
# 57623    I never wanted to go  \nI never wanted a way  ...
# 57624    Why's this motherfucker lookin' at me  \nIs th...
# 57625    Hell yeah, woo  \nPunk rock trippin' with the ...
# 57626    Hello tomorrow and good-bye to yesterday  \nWe...
# 57627    Here she comes to ruin my day again  \nRight a...
# 57628    Anesthetized by these lies  \nI don't believe ...
# 57629    Well I'm tired, so tired of getting up and was...
# 57630    Drop in, hey  \n  \nCall us degenerate, heads ...
# 57631    'Cause I'm a user  \nA schmoozer  \nA big doll...
# 57632    I've got girls, they're in my room  \nThe only...
# 57633    We got bruised wrists, kick flips, sending an ...
# 57634    Let it ride  \nHow did everything get messed u...
# 57635    Well some wear their feelings right on their s...
# 57636    Enrique played in a band  \nDown at the sand  ...
# 57637    You can lie to me and say it's you I adore  \n...
# 57638    Let's go  \nThe lights are on but there is no ...
# 57639    I know a girl who welcomes the world  \nI thin...
# 57640    Lie to me  \nTell me that everything will be a...
# 57641    That's why I'm marching, yes, I'm marching,  \...
# 57642    [Chorus]  \nI wanna thank you for the things y...
# 57643    Seven richest countries in the world  \nThem h...
# 57644    Many generation have passed away  \nFighting f...
# 57645    Irie days come on play  \nLet the angels fly l...
# 57646    Power to the workers  \nMore power  \nPower to...
# 57647    all you need  \nis something i'll believe  \nf...
# 57648    northern star  \nam i frightened  \nwhere can ...
# 57649    come in  \nmake yourself at home  \ni'm a bit ...
# Name: text, Length: 57650, dtype: object

# %%
data=np.array(df)
print(data)
# Out:
# ["Look at her face, it's a wonderful face  \nAnd it means something special to me  \nLook at the way that she smiles when she sees me  \nHow lucky can one fellow be?  \n  \nShe's just my kind of girl, she makes me feel fine  \nWho could ever believe that she could be mine?  \nShe's just my kind of girl, without her I'm blue  \nAnd if she ever leaves me what could I do, what could I do?  \n  \nAnd when we go for a walk in the park  \nAnd she holds me and squeezes my hand  \nWe'll go on walking for hours and talking  \nAbout all the things that we plan  \n  \nShe's just my kind of girl, she makes me feel fine  \nWho could ever believe that she could be mine?  \nShe's just my kind of girl, without her I'm blue  \nAnd if she ever leaves me what could I do, what could I do?\n\n"
#  "Take it easy with me, please  \nTouch me gently like a summer evening breeze  \nTake your time, make it slow  \nAndante, Andante  \nJust let the feeling grow  \n  \nMake your fingers soft and light  \nLet your body be the velvet of the night  \nTouch my soul, you know how  \nAndante, Andante  \nGo slowly with me now  \n  \nI'm your music  \n(I am your music and I am your song)  \nI'm your song  \n(I am your music and I am your song)  \nPlay me time and time again and make me strong  \n(Play me again 'cause you're making me strong)  \nMake me sing, make me sound  \n(You make me sing and you make me)  \nAndante, Andante  \nTread lightly on my ground  \nAndante, Andante  \nOh please don't let me down  \n  \nThere's a shimmer in your eyes  \nLike the feeling of a thousand butterflies  \nPlease don't talk, go on, play  \nAndante, Andante  \nAnd let me float away  \n  \nI'm your music  \n(I am your music and I am your song)  \nI'm your song  \n(I am your music and I am your song)  \nPlay me time and time again and make me strong  \n(Play me again 'cause you're making me strong)  \nMake me sing, make me sound  \n(You make me sing and you make me)  \nAndante, Andante  \nTread lightly on my ground  \nAndante, Andante  \nOh please don't let me down  \n  \nMake me sing, make me sound  \n(You make me sing and you make me)  \nAndante, Andante  \nTread lightly on my ground  \nAndante, Andante  \nOh please don't let me down  \nAndante, Andante  \nOh please don't let me down\n\n"
#  "I'll never know why I had to go  \nWhy I had to put up such a lousy rotten show  \nBoy, I was tough, packing all my stuff  \nSaying I don't need you anymore, I've had enough  \nAnd now, look at me standing here again 'cause I found out that  \nMa ma ma ma ma ma ma ma ma ma ma ma ma ma ma ma my life is here  \nGotta have you near  \n  \nAs good as new, my love for you  \nAnd keeping it that way is my intention  \nAs good as new and growing too  \nYes, I think it's taking on a new dimension  \nIt's as good as new, my love for you  \nJust like it used to be and even better  \nAs good as new, thank God it's true  \nDarling, we were always meant to stay together  \n  \nFeel like a creep, never felt so cheap  \nNever had a notion that my love could be so deep  \nHow could I make such a dumb mistake  \nNow I know I'm not entitled to another break  \nBut please, baby, I beg you to forgive 'cause I found out that  \nMa ma ma ma ma ma ma ma ma ma ma ma ma ma ma ma my life is here  \nGotta get you near  \n  \nI thought that our love was at an end but here I am again  \n  \nAs good as new, my love for you  \nAnd keeping it that way is my intention  \nAs good as new and growing too  \nYes, I think it's taking on a new dimension  \nIt's as good as new, my love for you  \nJust like it used to be and even better  \nAs good as new, thank God it's true  \nDarling, we were always meant to stay together  \n  \nYes the love I have for you feels as good as new  \nDarling, we were always meant to stay together\n\n"
#  ...
#  "all you need  \nis something i'll believe  \nflashlights in the hall  \nbut no call  \ncause when my day is done  \ni find where i belong  \nwaiting on the curb  \nfor you to come to carry on  \nit won't be long  \nwe'll turn around  \ni care enough to wake you up  \nto make us mine i'll make you shine  \n  \nstay the night  \nstay all your life  \njust come with me  \n  \ncome with me  \nwon't you come with me  \ncome with me again  \ncome with me  \n(stay the night)  \nwon't you come with me  \n(stay all your life)  \ncome with me again  \n(just come with me)  \n  \nfell so high i broke my jaw  \ni couldn't talk to you  \nwent underground to play around it's true  \nbut i came back  \nto get you at that place so i could breathe  \n  \nit's 3 a.m.  \nand i'm up again  \nanswering the call of all  \nthe flowers by the bed  \nmake me wish my head  \nwas lying and possessed by truth alone a certain home  \na wooden gate, a rabbit hole  \nwe'll turn around it won't be long  \ncapture that place, won't it be fun  \n  \ncome with me  \n(stay the night)  \nwon't you come with me  \n(stay all your life)  \ncome with me again  \n(just come with me)  \ncome with me  \n(stay the night)  \nwon't you come with me  \n(stay all your life)  \ncome with me again  \n(just come with me)  \n  \nshe means more to me  \nthan any living thing  \nyounger than the blush of spring she sings  \n  \n(stay the night)  \nwon't you come with me  \n(stay all your life)  \ncome with me again  \n(just come with me)  \n\n"
#  "northern star  \nam i frightened  \nwhere can i go to rest  \ni can't sleep  \nand i'm still fighting  \nwait, don't breathe  \n  \nthe time destroys a man  \na child who understands  \nthat anyone who desires  \nis not my kind  \nnot my truth  \n  \nfade away, it's all we do  \nfade away from the truth  \ndesires  \nfade away  \ndesires  \nfade away  \ndesires  \n  \nand northern star  \nplease enlighten  \nthe lost prayers of my soul  \nchildhood dreams  \nof death and titans  \nwe were meant to be free  \n  \nto give ourselves away  \nso please don't be afraid  \nof anyone who desires  \nthey're not my kind  \nnot my truth  \n  \nfade away, it's all we do  \nfade away from the truth  \ndesires  \nfade away  \ndesires  \nfade away  \ndesires  \nfade away  \ndesires  \n  \n'cause anyone who desires  \nis not my kind  \ni have no use for you  \n  \n\n"
#  "come in  \nmake yourself at home  \ni'm a bit late  \nhate to make you wait  \n  \nbut heart songs  \nare still on my mind  \nthere's never the time  \nto write down these lines  \n  \nhow can you say  \nthat i don't need you  \njust be sure  \nno more, no less  \nlet love confess to you  \nwhat you must do  \n  \ncome on  \nlet's hit the road  \ni'm up to my tricks  \ni know they seem cold  \n  \nbut heart songs  \nare all that i am  \ni use the same words  \nto say the same things  \n  \nhow can you say  \nthat i don't need you  \njust be sure  \nno more, no less  \nlet love confess to you  \nwhat you must do  \n  \nhow can you say  \nthat i don't need you  \njust be sure  \nno more, no less  \nlet love confess to you  \nno less\n\n"]

# %%
corpus=''
for ix in range(len(data)):
    corpus+=data[ix]

# %%
corpus

# %%
vocab=list(set(corpus))
char_ix={c:i for i,c in enumerate(vocab)}
ix_char={i:c for i,c in enumerate(vocab)}

# %%
char_ix
# Out:
# {'-': 0,
#  ' ': 1,
#  'M': 2,
#  'i': 3,
#  'Q': 4,
#  '‘': 5,
#  '.': 6,
#  's': 7,
#  'P': 8,
#  'á': 9,
#  '/': 10,
#  '(': 11,
#  'F': 12,
#  'C': 13,
#  '’': 14,
#  'n': 15,
#  ':': 16,
#  'ñ': 17,
#  '4': 18,
#  ';': 19,
#  'è': 20,
#  'Y': 21,
#  ']': 22,
#  'J': 23,
#  'z': 24,
#  'W': 25,
#  'g': 26,
#  ',': 27,
#  'q': 28,
#  'G': 29,
#  '*': 30,
#  'V': 31,
#  '…': 32,
#  'A': 33,
#  '7': 34,
#  '!': 35,
#  'j': 36,
#  'e': 37,
#  'D': 38,
#  'r': 39,
#  '—': 40,
#  'L': 41,
#  '0': 42,
#  'H': 43,
#  'o': 44,
#  '3': 45,
#  'K': 46,
#  'x': 47,
#  'é': 48,
#  'R': 49,
#  'u': 50,
#  'U': 51,
#  'y': 52,
#  'E': 53,
#  'h': 54,
#  't': 55,
#  '6': 56,
#  '[': 57,
#  '\\': 58,
#  '“': 59,
#  'c': 60,
#  '8': 61,
#  'S': 62,
#  '"': 63,
#  '1': 64,
#  '2': 65,
#  'l': 66,
#  'p': 67,
#  'k': 68,
#  'I': 69,
#  '?': 70,
#  ')': 71,
#  'N': 72,
#  'O': 73,
#  "'": 74,
#  'v': 75,
#  'm': 76,
#  'a': 77,
#  '9': 78,
#  'B': 79,
#  'd': 80,
#  'f': 81,
#  'w': 82,
#  'T': 83,
#  'b': 84}

# %%
ix_char
# Out:
# {0: '-',
#  1: 'Q',
#  2: 'z',
#  3: 'q',
#  4: 'D',
#  5: 'N',
#  6: 'E',
#  7: 'M',
#  8: 'f',
#  9: ',',
#  10: 'Y',
#  11: 'O',
#  12: 'S',
#  13: 'J',
#  14: ')',
#  15: '6',
#  16: 'F',
#  17: 'o',
#  18: '9',
#  19: 'x',
#  20: '0',
#  21: '8',
#  22: 'h',
#  23: '"',
#  24: '(',
#  25: '1',
#  26: '5',
#  27: '7',
#  28: 'V',
#  29: 'A',
#  30: 'X',
#  31: 'u',
#  32: '3',
#  33: '2',
#  34: 'L',
#  35: 'm',
#  36: 'n',
#  37: 'w',
#  38: '!',
#  39: 'Z',
#  40: 'i',
#  41: 'C',
#  42: 'R',
#  43: 'B',
#  44: 'P',
#  45: "'",
#  46: '[',
#  47: 'K',
#  48: 'y',
#  49: '?',
#  50: ']',
#  51: 's',
#  52: 'v',
#  53: '4',
#  54: 'l',
#  55: 'd',
#  56: '\n',
#  57: 'U',
#  58: '.',
#  59: 'r',
#  60: 'H',
#  61: ':',
#  62: 'j',
#  63: 'G',
#  64: 'a',
#  65: 'p',
#  66: 'k',
#  67: ' ',
#  68: 'T',
#  69: 'e',
#  70: 'b',
#  71: 'W',
#  72: 'c',
#  73: 'I',
#  74: 't',
#  75: 'g'}

# %%
maxlen=40
vocab_size=len(vocab)

# %%
sentences=[]
next_char=[]
for i in range(len(corpus)-maxlen-1):
    sentences.append(corpus[i:i+maxlen])
    next_char.append(corpus[i+maxlen])

# %%
sentences
# Out:
# ["Look at her face, it's a wonderful face ",
#  "ook at her face, it's a wonderful face  ",
#  "ok at her face, it's a wonderful face  \n",
#  "k at her face, it's a wonderful face  \nA",
#  " at her face, it's a wonderful face  \nAn",
#  "at her face, it's a wonderful face  \nAnd",
#  "t her face, it's a wonderful face  \nAnd ",
#  " her face, it's a wonderful face  \nAnd i",
#  "her face, it's a wonderful face  \nAnd it",
#  "er face, it's a wonderful face  \nAnd it ",
#  "r face, it's a wonderful face  \nAnd it m",
#  " face, it's a wonderful face  \nAnd it me",
#  "face, it's a wonderful face  \nAnd it mea",
#  "ace, it's a wonderful face  \nAnd it mean",
#  "ce, it's a wonderful face  \nAnd it means",
#  "e, it's a wonderful face  \nAnd it means ",
#  ", it's a wonderful face  \nAnd it means s",
#  " it's a wonderful face  \nAnd it means so",
#  "it's a wonderful face  \nAnd it means som",
#  "t's a wonderful face  \nAnd it means some",
#  "'s a wonderful face  \nAnd it means somet",
#  's a wonderful face  \nAnd it means someth',
#  ' a wonderful face  \nAnd it means somethi',
#  'a wonderful face  \nAnd it means somethin',
#  ' wonderful face  \nAnd it means something',
#  'wonderful face  \nAnd it means something ',
#  'onderful face  \nAnd it means something s',
#  'nderful face  \nAnd it means something sp',
#  'derful face  \nAnd it means something spe',
#  'erful face  \nAnd it means something spec',
#  'rful face  \nAnd it means something speci',
#  'ful face  \nAnd it means something specia',
#  'ul face  \nAnd it means something special',
#  'l face  \nAnd it means something special ',
#  ' face  \nAnd it means something special t',
#  'face  \nAnd it means something special to',
#  'ace  \nAnd it means something special to ',
#  'ce  \nAnd it means something special to m',
#  'e  \nAnd it means something special to me',
#  '  \nAnd it means something special to me ',
#  ' \nAnd it means something special to me  ',
#  '\nAnd it means something special to me  \n',
#  'And it means something special to me  \nL',
#  'nd it means something special to me  \nLo',
#  'd it means something special to me  \nLoo',
#  ' it means something special to me  \nLook',
#  'it means something special to me  \nLook ',
#  't means something special to me  \nLook a',
#  ' means something special to me  \nLook at',
#  'means something special to me  \nLook at ',
#  'eans something special to me  \nLook at t',
#  'ans something special to me  \nLook at th',
#  'ns something special to me  \nLook at the',
#  's something special to me  \nLook at the ',
#  ' something special to me  \nLook at the w',
#  'something special to me  \nLook at the wa',
#  'omething special to me  \nLook at the way',
#  'mething special to me  \nLook at the way ',
#  'ething special to me  \nLook at the way t',
#  'thing special to me  \nLook at the way th',
#  'hing special to me  \nLook at the way tha',
#  'ing special to me  \nLook at the way that',
#  'ng special to me  \nLook at the way that ',
#  'g special to me  \nLook at the way that s',
#  ' special to me  \nLook at the way that sh',
#  'special to me  \nLook at the way that she',
#  'pecial to me  \nLook at the way that she ',
#  'ecial to me  \nLook at the way that she s',
#  'cial to me  \nLook at the way that she sm',
#  'ial to me  \nLook at the way that she smi',
#  'al to me  \nLook at the way that she smil',
#  'l to me  \nLook at the way that she smile',
#  ' to me  \nLook at the way that she smiles',
#  'to me  \nLook at the way that she smiles ',
#  'o me  \nLook at the way that she smiles w',
#  ' me  \nLook at the way that she smiles wh',
#  'me  \nLook at the way that she smiles whe',
#  'e  \nLook at the way that she smiles when',
#  '  \nLook at the way that she smiles when ',
#  ' \nLook at the way that she smiles when s',
#  '\nLook at the way that she smiles when sh',
#  'Look at the way that she smiles when she',
#  'ook at the way that she smiles when she ',
#  'ok at the way that she smiles when she s',
#  'k at the way that she smiles when she se',
#  ' at the way that she smiles when she see',
#  'at the way that she smiles when she sees',
#  't the way that she smiles when she sees ',
#  ' the way that she smiles when she sees m',
#  'the way that she smiles when she sees me',
#  'he way that she smiles when she sees me ',
#  'e way that she smiles when she sees me  ',
#  ' way that she smiles when she sees me  \n',
#  'way that she smiles when she sees me  \nH',
#  'ay that she smiles when she sees me  \nHo',
#  'y that she smiles when she sees me  \nHow',
#  ' that she smiles when she sees me  \nHow ',
#  'that she smiles when she sees me  \nHow l',
#  'hat she smiles when she sees me  \nHow lu',
#  'at she smiles when she sees me  \nHow luc',
#  't she smiles when she sees me  \nHow luck',
#  ' she smiles when she sees me  \nHow lucky',
#  'she smiles when she sees me  \nHow lucky ',
#  'he smiles when she sees me  \nHow lucky c',
#  'e smiles when she sees me  \nHow lucky ca',
#  ' smiles when she sees me  \nHow lucky can',
#  'smiles when she sees me  \nHow lucky can ',
#  'miles when she sees me  \nHow lucky can o',
#  'iles when she sees me  \nHow lucky can on',
#  'les when she sees me  \nHow lucky can one',
#  'es when she sees me  \nHow lucky can one ',
#  's when she sees me  \nHow lucky can one f',
#  ' when she sees me  \nHow lucky can one fe',
#  'when she sees me  \nHow lucky can one fel',
#  'hen she sees me  \nHow lucky can one fell',
#  'en she sees me  \nHow lucky can one fello',
#  'n she sees me  \nHow lucky can one fellow',
#  ' she sees me  \nHow lucky can one fellow ',
#  'she sees me  \nHow lucky can one fellow b',
#  'he sees me  \nHow lucky can one fellow be',
#  'e sees me  \nHow lucky can one fellow be?',
#  ' sees me  \nHow lucky can one fellow be? ',
#  'sees me  \nHow lucky can one fellow be?  ',
#  'ees me  \nHow lucky can one fellow be?  \n',
#  'es me  \nHow lucky can one fellow be?  \n ',
#  's me  \nHow lucky can one fellow be?  \n  ',
#  ' me  \nHow lucky can one fellow be?  \n  \n',
#  'me  \nHow lucky can one fellow be?  \n  \nS',
#  'e  \nHow lucky can one fellow be?  \n  \nSh',
#  '  \nHow lucky can one fellow be?  \n  \nShe',
#  " \nHow lucky can one fellow be?  \n  \nShe'",
#  "\nHow lucky can one fellow be?  \n  \nShe's",
#  "How lucky can one fellow be?  \n  \nShe's ",
#  "ow lucky can one fellow be?  \n  \nShe's j",
#  "w lucky can one fellow be?  \n  \nShe's ju",
#  " lucky can one fellow be?  \n  \nShe's jus",
#  "lucky can one fellow be?  \n  \nShe's just",
#  "ucky can one fellow be?  \n  \nShe's just ",
#  "cky can one fellow be?  \n  \nShe's just m",
#  "ky can one fellow be?  \n  \nShe's just my",
#  "y can one fellow be?  \n  \nShe's just my ",
#  " can one fellow be?  \n  \nShe's just my k",
#  "can one fellow be?  \n  \nShe's just my ki",
#  "an one fellow be?  \n  \nShe's just my kin",
#  "n one fellow be?  \n  \nShe's just my kind",
#  " one fellow be?  \n  \nShe's just my kind ",
#  "one fellow be?  \n  \nShe's just my kind o",
#  "ne fellow be?  \n  \nShe's just my kind of",
#  "e fellow be?  \n  \nShe's just my kind of ",
#  " fellow be?  \n  \nShe's just my kind of g",
#  "fellow be?  \n  \nShe's just my kind of gi",
#  "ellow be?  \n  \nShe's just my kind of gir",
#  "llow be?  \n  \nShe's just my kind of girl",
#  "low be?  \n  \nShe's just my kind of girl,",
#  "ow be?  \n  \nShe's just my kind of girl, ",
#  "w be?  \n  \nShe's just my kind of girl, s",
#  " be?  \n  \nShe's just my kind of girl, sh",
#  "be?  \n  \nShe's just my kind of girl, she",
#  "e?  \n  \nShe's just my kind of girl, she ",
#  "?  \n  \nShe's just my kind of girl, she m",
#  "  \n  \nShe's just my kind of girl, she ma",
#  " \n  \nShe's just my kind of girl, she mak",
#  "\n  \nShe's just my kind of girl, she make",
#  "  \nShe's just my kind of girl, she makes",
#  " \nShe's just my kind of girl, she makes ",
#  "\nShe's just my kind of girl, she makes m",
#  "She's just my kind of girl, she makes me",
#  "he's just my kind of girl, she makes me ",
#  "e's just my kind of girl, she makes me f",
#  "'s just my kind of girl, she makes me fe",
#  's just my kind of girl, she makes me fee',
#  ' just my kind of girl, she makes me feel',
#  'just my kind of girl, she makes me feel ',
#  'ust my kind of girl, she makes me feel f',
#  'st my kind of girl, she makes me feel fi',
#  't my kind of girl, she makes me feel fin',
#  ' my kind of girl, she makes me feel fine',
#  'my kind of girl, she makes me feel fine ',
#  'y kind of girl, she makes me feel fine  ',
#  ' kind of girl, she makes me feel fine  \n',
#  'kind of girl, she makes me feel fine  \nW',
#  'ind of girl, she makes me feel fine  \nWh',
#  'nd of girl, she makes me feel fine  \nWho',
#  'd of girl, she makes me feel fine  \nWho ',
#  ' of girl, she makes me feel fine  \nWho c',
#  'of girl, she makes me feel fine  \nWho co',
#  'f girl, she makes me feel fine  \nWho cou',
#  ' girl, she makes me feel fine  \nWho coul',
#  'girl, she makes me feel fine  \nWho could',
#  'irl, she makes me feel fine  \nWho could ',
#  'rl, she makes me feel fine  \nWho could e',
#  'l, she makes me feel fine  \nWho could ev',
#  ', she makes me feel fine  \nWho could eve',
#  ' she makes me feel fine  \nWho could ever',
#  'she makes me feel fine  \nWho could ever ',
#  'he makes me feel fine  \nWho could ever b',
#  'e makes me feel fine  \nWho could ever be',
#  ' makes me feel fine  \nWho could ever bel',
#  'makes me feel fine  \nWho could ever beli',
#  'akes me feel fine  \nWho could ever belie',
#  'kes me feel fine  \nWho could ever believ',
#  'es me feel fine  \nWho could ever believe',
#  's me feel fine  \nWho could ever believe ',
#  ' me feel fine  \nWho could ever believe t',
#  'me feel fine  \nWho could ever believe th',
#  'e feel fine  \nWho could ever believe tha',
#  ' feel fine  \nWho could ever believe that',
#  'feel fine  \nWho could ever believe that ',
#  'eel fine  \nWho could ever believe that s',
#  'el fine  \nWho could ever believe that sh',
#  'l fine  \nWho could ever believe that she',
#  ' fine  \nWho could ever believe that she ',
#  'fine  \nWho could ever believe that she c',
#  'ine  \nWho could ever believe that she co',
#  'ne  \nWho could ever believe that she cou',
#  'e  \nWho could ever believe that she coul',
#  '  \nWho could ever believe that she could',
#  ' \nWho could ever believe that she could ',
#  '\nWho could ever believe that she could b',
#  'Who could ever believe that she could be',
#  'ho could ever believe that she could be ',
#  'o could ever believe that she could be m',
#  ' could ever believe that she could be mi',
#  'could ever believe that she could be min',
#  'ould ever believe that she could be mine',
#  'uld ever believe that she could be mine?',
#  'ld ever believe that she could be mine? ',
#  'd ever believe that she could be mine?  ',
#  ' ever believe that she could be mine?  \n',
#  'ever believe that she could be mine?  \nS',
#  'ver believe that she could be mine?  \nSh',
#  'er believe that she could be mine?  \nShe',
#  "r believe that she could be mine?  \nShe'",
#  " believe that she could be mine?  \nShe's",
#  "believe that she could be mine?  \nShe's ",
#  "elieve that she could be mine?  \nShe's j",
#  "lieve that she could be mine?  \nShe's ju",
#  "ieve that she could be mine?  \nShe's jus",
#  "eve that she could be mine?  \nShe's just",
#  "ve that she could be mine?  \nShe's just ",
#  "e that she could be mine?  \nShe's just m",
#  " that she could be mine?  \nShe's just my",
#  "that she could be mine?  \nShe's just my ",
#  "hat she could be mine?  \nShe's just my k",
#  "at she could be mine?  \nShe's just my ki",
#  "t she could be mine?  \nShe's just my kin",
#  " she could be mine?  \nShe's just my kind",
#  "she could be mine?  \nShe's just my kind ",
#  "he could be mine?  \nShe's just my kind o",
#  "e could be mine?  \nShe's just my kind of",
#  " could be mine?  \nShe's just my kind of ",
#  "could be mine?  \nShe's just my kind of g",
#  "ould be mine?  \nShe's just my kind of gi",
#  "uld be mine?  \nShe's just my kind of gir",
#  "ld be mine?  \nShe's just my kind of girl",
#  "d be mine?  \nShe's just my kind of girl,",
#  " be mine?  \nShe's just my kind of girl, ",
#  "be mine?  \nShe's just my kind of girl, w",
#  "e mine?  \nShe's just my kind of girl, wi",
#  " mine?  \nShe's just my kind of girl, wit",
#  "mine?  \nShe's just my kind of girl, with",
#  "ine?  \nShe's just my kind of girl, witho",
#  "ne?  \nShe's just my kind of girl, withou",
#  "e?  \nShe's just my kind of girl, without",
#  "?  \nShe's just my kind of girl, without ",
#  "  \nShe's just my kind of girl, without h",
#  " \nShe's just my kind of girl, without he",
#  "\nShe's just my kind of girl, without her",
#  "She's just my kind of girl, without her ",
#  "he's just my kind of girl, without her I",
#  "e's just my kind of girl, without her I'",
#  "'s just my kind of girl, without her I'm",
#  "s just my kind of girl, without her I'm ",
#  " just my kind of girl, without her I'm b",
#  "just my kind of girl, without her I'm bl",
#  "ust my kind of girl, without her I'm blu",
#  "st my kind of girl, without her I'm blue",
#  "t my kind of girl, without her I'm blue ",
#  " my kind of girl, without her I'm blue  ",
#  "my kind of girl, without her I'm blue  \n",
#  "y kind of girl, without her I'm blue  \nA",
#  " kind of girl, without her I'm blue  \nAn",
#  "kind of girl, without her I'm blue  \nAnd",
#  "ind of girl, without her I'm blue  \nAnd ",
#  "nd of girl, without her I'm blue  \nAnd i",
#  "d of girl, without her I'm blue  \nAnd if",
#  " of girl, without her I'm blue  \nAnd if ",
#  "of girl, without her I'm blue  \nAnd if s",
#  "f girl, without her I'm blue  \nAnd if sh",
#  " girl, without her I'm blue  \nAnd if she",
#  "girl, without her I'm blue  \nAnd if she ",
#  "irl, without her I'm blue  \nAnd if she e",
#  "rl, without her I'm blue  \nAnd if she ev",
#  "l, without her I'm blue  \nAnd if she eve",
#  ", without her I'm blue  \nAnd if she ever",
#  " without her I'm blue  \nAnd if she ever ",
#  "without her I'm blue  \nAnd if she ever l",
#  "ithout her I'm blue  \nAnd if she ever le",
#  "thout her I'm blue  \nAnd if she ever lea",
#  "hout her I'm blue  \nAnd if she ever leav",
#  "out her I'm blue  \nAnd if she ever leave",
#  "ut her I'm blue  \nAnd if she ever leaves",
#  "t her I'm blue  \nAnd if she ever leaves ",
#  " her I'm blue  \nAnd if she ever leaves m",
#  "her I'm blue  \nAnd if she ever leaves me",
#  "er I'm blue  \nAnd if she ever leaves me ",
#  "r I'm blue  \nAnd if she ever leaves me w",
#  " I'm blue  \nAnd if she ever leaves me wh",
#  "I'm blue  \nAnd if she ever leaves me wha",
#  "'m blue  \nAnd if she ever leaves me what",
#  'm blue  \nAnd if she ever leaves me what ',
#  ' blue  \nAnd if she ever leaves me what c',
#  'blue  \nAnd if she ever leaves me what co',
#  'lue  \nAnd if she ever leaves me what cou',
#  'ue  \nAnd if she ever leaves me what coul',
#  'e  \nAnd if she ever leaves me what could',
#  '  \nAnd if she ever leaves me what could ',
#  ' \nAnd if she ever leaves me what could I',
#  '\nAnd if she ever leaves me what could I ',
#  'And if she ever leaves me what could I d',
#  'nd if she ever leaves me what could I do',
#  'd if she ever leaves me what could I do,',
#  ' if she ever leaves me what could I do, ',
#  'if she ever leaves me what could I do, w',
#  'f she ever leaves me what could I do, wh',
#  ' she ever leaves me what could I do, wha',
#  'she ever leaves me what could I do, what',
#  'he ever leaves me what could I do, what ',
#  'e ever leaves me what could I do, what c',
#  ' ever leaves me what could I do, what co',
#  'ever leaves me what could I do, what cou',
#  'ver leaves me what could I do, what coul',
#  'er leaves me what could I do, what could',
#  'r leaves me what could I do, what could ',
#  ' leaves me what could I do, what could I',
#  'leaves me what could I do, what could I ',
#  'eaves me what could I do, what could I d',
#  'aves me what could I do, what could I do',
#  'ves me what could I do, what could I do?',
#  'es me what could I do, what could I do? ',
#  's me what could I do, what could I do?  ',
#  ' me what could I do, what could I do?  \n',
#  'me what could I do, what could I do?  \n ',
#  'e what could I do, what could I do?  \n  ',
#  ' what could I do, what could I do?  \n  \n',
#  'what could I do, what could I do?  \n  \nA',
#  'hat could I do, what could I do?  \n  \nAn',
#  'at could I do, what could I do?  \n  \nAnd',
#  't could I do, what could I do?  \n  \nAnd ',
#  ' could I do, what could I do?  \n  \nAnd w',
#  'could I do, what could I do?  \n  \nAnd wh',
#  'ould I do, what could I do?  \n  \nAnd whe',
#  'uld I do, what could I do?  \n  \nAnd when',
#  'ld I do, what could I do?  \n  \nAnd when ',
#  'd I do, what could I do?  \n  \nAnd when w',
#  ' I do, what could I do?  \n  \nAnd when we',
#  'I do, what could I do?  \n  \nAnd when we ',
#  ' do, what could I do?  \n  \nAnd when we g',
#  'do, what could I do?  \n  \nAnd when we go',
#  'o, what could I do?  \n  \nAnd when we go ',
#  ', what could I do?  \n  \nAnd when we go f',
#  ' what could I do?  \n  \nAnd when we go fo',
#  'what could I do?  \n  \nAnd when we go for',
#  'hat could I do?  \n  \nAnd when we go for ',
#  'at could I do?  \n  \nAnd when we go for a',
#  't could I do?  \n  \nAnd when we go for a ',
#  ' could I do?  \n  \nAnd when we go for a w',
#  'could I do?  \n  \nAnd when we go for a wa',
#  'ould I do?  \n  \nAnd when we go for a wal',
#  'uld I do?  \n  \nAnd when we go for a walk',
#  'ld I do?  \n  \nAnd when we go for a walk ',
#  'd I do?  \n  \nAnd when we go for a walk i',
#  ' I do?  \n  \nAnd when we go for a walk in',
#  'I do?  \n  \nAnd when we go for a walk in ',
#  ' do?  \n  \nAnd when we go for a walk in t',
#  'do?  \n  \nAnd when we go for a walk in th',
#  'o?  \n  \nAnd when we go for a walk in the',
#  '?  \n  \nAnd when we go for a walk in the ',
#  '  \n  \nAnd when we go for a walk in the p',
#  ' \n  \nAnd when we go for a walk in the pa',
#  '\n  \nAnd when we go for a walk in the par',
#  '  \nAnd when we go for a walk in the park',
#  ' \nAnd when we go for a walk in the park ',
#  '\nAnd when we go for a walk in the park  ',
#  'And when we go for a walk in the park  \n',
#  'nd when we go for a walk in the park  \nA',
#  'd when we go for a walk in the park  \nAn',
#  ' when we go for a walk in the park  \nAnd',
#  'when we go for a walk in the park  \nAnd ',
#  'hen we go for a walk in the park  \nAnd s',
#  'en we go for a walk in the park  \nAnd sh',
#  'n we go for a walk in the park  \nAnd she',
#  ' we go for a walk in the park  \nAnd she ',
#  'we go for a walk in the park  \nAnd she h',
#  'e go for a walk in the park  \nAnd she ho',
#  ' go for a walk in the park  \nAnd she hol',
#  'go for a walk in the park  \nAnd she hold',
#  'o for a walk in the park  \nAnd she holds',
#  ' for a walk in the park  \nAnd she holds ',
#  'for a walk in the park  \nAnd she holds m',
#  'or a walk in the park  \nAnd she holds me',
#  'r a walk in the park  \nAnd she holds me ',
#  ' a walk in the park  \nAnd she holds me a',
#  'a walk in the park  \nAnd she holds me an',
#  ' walk in the park  \nAnd she holds me and',
#  'walk in the park  \nAnd she holds me and ',
#  'alk in the park  \nAnd she holds me and s',
#  'lk in the park  \nAnd she holds me and sq',
#  'k in the park  \nAnd she holds me and squ',
#  ' in the park  \nAnd she holds me and sque',
#  'in the park  \nAnd she holds me and squee',
#  'n the park  \nAnd she holds me and squeez',
#  ' the park  \nAnd she holds me and squeeze',
#  'the park  \nAnd she holds me and squeezes',
#  'he park  \nAnd she holds me and squeezes ',
#  'e park  \nAnd she holds me and squeezes m',
#  ' park  \nAnd she holds me and squeezes my',
#  'park  \nAnd she holds me and squeezes my ',
#  'ark  \nAnd she holds me and squeezes my h',
#  'rk  \nAnd she holds me and squeezes my ha',
#  'k  \nAnd she holds me and squeezes my han',
#  '  \nAnd she holds me and squeezes my hand',
#  ' \nAnd she holds me and squeezes my hand ',
#  '\nAnd she holds me and squeezes my hand  ',
#  'And she holds me and squeezes my hand  \n',
#  'nd she holds me and squeezes my hand  \nW',
#  'd she holds me and squeezes my hand  \nWe',
#  " she holds me and squeezes my hand  \nWe'",
#  "she holds me and squeezes my hand  \nWe'l",
#  "he holds me and squeezes my hand  \nWe'll",
#  "e holds me and squeezes my hand  \nWe'll ",
#  " holds me and squeezes my hand  \nWe'll g",
#  "holds me and squeezes my hand  \nWe'll go",
#  "olds me and squeezes my hand  \nWe'll go ",
#  "lds me and squeezes my hand  \nWe'll go o",
#  "ds me and squeezes my hand  \nWe'll go on",
#  "s me and squeezes my hand  \nWe'll go on ",
#  " me and squeezes my hand  \nWe'll go on w",
#  "me and squeezes my hand  \nWe'll go on wa",
#  "e and squeezes my hand  \nWe'll go on wal",
#  " and squeezes my hand  \nWe'll go on walk",
#  "and squeezes my hand  \nWe'll go on walki",
#  "nd squeezes my hand  \nWe'll go on walkin",
#  "d squeezes my hand  \nWe'll go on walking",
#  " squeezes my hand  \nWe'll go on walking ",
#  "squeezes my hand  \nWe'll go on walking f",
#  "queezes my hand  \nWe'll go on walking fo",
#  "ueezes my hand  \nWe'll go on walking for",
#  "eezes my hand  \nWe'll go on walking for ",
#  "ezes my hand  \nWe'll go on walking for h",
#  "zes my hand  \nWe'll go on walking for ho",
#  "es my hand  \nWe'll go on walking for hou",
#  "s my hand  \nWe'll go on walking for hour",
#  " my hand  \nWe'll go on walking for hours",
#  "my hand  \nWe'll go on walking for hours ",
#  "y hand  \nWe'll go on walking for hours a",
#  " hand  \nWe'll go on walking for hours an",
#  "hand  \nWe'll go on walking for hours and",
#  "and  \nWe'll go on walking for hours and ",
#  "nd  \nWe'll go on walking for hours and t",
#  "d  \nWe'll go on walking for hours and ta",
#  "  \nWe'll go on walking for hours and tal",
#  " \nWe'll go on walking for hours and talk",
#  "\nWe'll go on walking for hours and talki",
#  "We'll go on walking for hours and talkin",
#  "e'll go on walking for hours and talking",
#  "'ll go on walking for hours and talking ",
#  'll go on walking for hours and talking  ',
#  'l go on walking for hours and talking  \n',
#  ' go on walking for hours and talking  \nA',
#  'go on walking for hours and talking  \nAb',
#  'o on walking for hours and talking  \nAbo',
#  ' on walking for hours and talking  \nAbou',
#  'on walking for hours and talking  \nAbout',
#  'n walking for hours and talking  \nAbout ',
#  ' walking for hours and talking  \nAbout a',
#  'walking for hours and talking  \nAbout al',
#  'alking for hours and talking  \nAbout all',
#  'lking for hours and talking  \nAbout all ',
#  'king for hours and talking  \nAbout all t',
#  'ing for hours and talking  \nAbout all th',
#  'ng for hours and talking  \nAbout all the',
#  'g for hours and talking  \nAbout all the ',
#  ' for hours and talking  \nAbout all the t',
#  'for hours and talking  \nAbout all the th',
#  'or hours and talking  \nAbout all the thi',
#  'r hours and talking  \nAbout all the thin',
#  ' hours and talking  \nAbout all the thing',
#  'hours and talking  \nAbout all the things',
#  'ours and talking  \nAbout all the things ',
#  'urs and talking  \nAbout all the things t',
#  'rs and talking  \nAbout all the things th',
#  's and talking  \nAbout all the things tha',
#  ' and talking  \nAbout all the things that',
#  'and talking  \nAbout all the things that ',
#  'nd talking  \nAbout all the things that w',
#  'd talking  \nAbout all the things that we',
#  ' talking  \nAbout all the things that we ',
#  'talking  \nAbout all the things that we p',
#  'alking  \nAbout all the things that we pl',
#  'lking  \nAbout all the things that we pla',
#  'king  \nAbout all the things that we plan',
#  'ing  \nAbout all the things that we plan ',
#  'ng  \nAbout all the things that we plan  ',
#  'g  \nAbout all the things that we plan  \n',
#  '  \nAbout all the things that we plan  \n ',
#  ' \nAbout all the things that we plan  \n  ',
#  '\nAbout all the things that we plan  \n  \n',
#  'About all the things that we plan  \n  \nS',
#  'bout all the things that we plan  \n  \nSh',
#  'out all the things that we plan  \n  \nShe',
#  "ut all the things that we plan  \n  \nShe'",
#  "t all the things that we plan  \n  \nShe's",
#  " all the things that we plan  \n  \nShe's ",
#  "all the things that we plan  \n  \nShe's j",
#  "ll the things that we plan  \n  \nShe's ju",
#  "l the things that we plan  \n  \nShe's jus",
#  " the things that we plan  \n  \nShe's just",
#  "the things that we plan  \n  \nShe's just ",
#  "he things that we plan  \n  \nShe's just m",
#  "e things that we plan  \n  \nShe's just my",
#  " things that we plan  \n  \nShe's just my ",
#  "things that we plan  \n  \nShe's just my k",
#  "hings that we plan  \n  \nShe's just my ki",
#  "ings that we plan  \n  \nShe's just my kin",
#  "ngs that we plan  \n  \nShe's just my kind",
#  "gs that we plan  \n  \nShe's just my kind ",
#  "s that we plan  \n  \nShe's just my kind o",
#  " that we plan  \n  \nShe's just my kind of",
#  "that we plan  \n  \nShe's just my kind of ",
#  "hat we plan  \n  \nShe's just my kind of g",
#  "at we plan  \n  \nShe's just my kind of gi",
#  "t we plan  \n  \nShe's just my kind of gir",
#  " we plan  \n  \nShe's just my kind of girl",
#  "we plan  \n  \nShe's just my kind of girl,",
#  "e plan  \n  \nShe's just my kind of girl, ",
#  " plan  \n  \nShe's just my kind of girl, s",
#  "plan  \n  \nShe's just my kind of girl, sh",
#  "lan  \n  \nShe's just my kind of girl, she",
#  "an  \n  \nShe's just my kind of girl, she ",
#  "n  \n  \nShe's just my kind of girl, she m",
#  "  \n  \nShe's just my kind of girl, she ma",
#  " \n  \nShe's just my kind of girl, she mak",
#  "\n  \nShe's just my kind of girl, she make",
#  "  \nShe's just my kind of girl, she makes",
#  " \nShe's just my kind of girl, she makes ",
#  "\nShe's just my kind of girl, she makes m",
#  "She's just my kind of girl, she makes me",
#  "he's just my kind of girl, she makes me ",
#  "e's just my kind of girl, she makes me f",
#  "'s just my kind of girl, she makes me fe",
#  's just my kind of girl, she makes me fee',
#  ' just my kind of girl, she makes me feel',
#  'just my kind of girl, she makes me feel ',
#  'ust my kind of girl, she makes me feel f',
#  'st my kind of girl, she makes me feel fi',
#  't my kind of girl, she makes me feel fin',
#  ' my kind of girl, she makes me feel fine',
#  'my kind of girl, she makes me feel fine ',
#  'y kind of girl, she makes me feel fine  ',
#  ' kind of girl, she makes me feel fine  \n',
#  'kind of girl, she makes me feel fine  \nW',
#  'ind of girl, she makes me feel fine  \nWh',
#  'nd of girl, she makes me feel fine  \nWho',
#  'd of girl, she makes me feel fine  \nWho ',
#  ' of girl, she makes me feel fine  \nWho c',
#  'of girl, she makes me feel fine  \nWho co',
#  'f girl, she makes me feel fine  \nWho cou',
#  ' girl, she makes me feel fine  \nWho coul',
#  'girl, she makes me feel fine  \nWho could',
#  'irl, she makes me feel fine  \nWho could ',
#  'rl, she makes me feel fine  \nWho could e',
#  'l, she makes me feel fine  \nWho could ev',
#  ', she makes me feel fine  \nWho could eve',
#  ' she makes me feel fine  \nWho could ever',
#  'she makes me feel fine  \nWho could ever ',
#  'he makes me feel fine  \nWho could ever b',
#  'e makes me feel fine  \nWho could ever be',
#  ' makes me feel fine  \nWho could ever bel',
#  'makes me feel fine  \nWho could ever beli',
#  'akes me feel fine  \nWho could ever belie',
#  'kes me feel fine  \nWho could ever believ',
#  'es me feel fine  \nWho could ever believe',
#  's me feel fine  \nWho could ever believe ',
#  ' me feel fine  \nWho could ever believe t',
#  'me feel fine  \nWho could ever believe th',
#  'e feel fine  \nWho could ever believe tha',
#  ' feel fine  \nWho could ever believe that',
#  'feel fine  \nWho could ever believe that ',
#  'eel fine  \nWho could ever believe that s',
#  'el fine  \nWho could ever believe that sh',
#  'l fine  \nWho could ever believe that she',
#  ' fine  \nWho could ever believe that she ',
#  'fine  \nWho could ever believe that she c',
#  'ine  \nWho could ever believe that she co',
#  'ne  \nWho could ever believe that she cou',
#  'e  \nWho could ever believe that she coul',
#  '  \nWho could ever believe that she could',
#  ' \nWho could ever believe that she could ',
#  '\nWho could ever believe that she could b',
#  'Who could ever believe that she could be',
#  'ho could ever believe that she could be ',
#  'o could ever believe that she could be m',
#  ' could ever believe that she could be mi',
#  'could ever believe that she could be min',
#  'ould ever believe that she could be mine',
#  'uld ever believe that she could be mine?',
#  'ld ever believe that she could be mine? ',
#  'd ever believe that she could be mine?  ',
#  ' ever believe that she could be mine?  \n',
#  'ever believe that she could be mine?  \nS',
#  'ver believe that she could be mine?  \nSh',
#  'er believe that she could be mine?  \nShe',
#  "r believe that she could be mine?  \nShe'",
#  " believe that she could be mine?  \nShe's",
#  "believe that she could be mine?  \nShe's ",
#  "elieve that she could be mine?  \nShe's j",
#  "lieve that she could be mine?  \nShe's ju",
#  "ieve that she could be mine?  \nShe's jus",
#  "eve that she could be mine?  \nShe's just",
#  "ve that she could be mine?  \nShe's just ",
#  "e that she could be mine?  \nShe's just m",
#  " that she could be mine?  \nShe's just my",
#  "that she could be mine?  \nShe's just my ",
#  "hat she could be mine?  \nShe's just my k",
#  "at she could be mine?  \nShe's just my ki",
#  "t she could be mine?  \nShe's just my kin",
#  " she could be mine?  \nShe's just my kind",
#  "she could be mine?  \nShe's just my kind ",
#  "he could be mine?  \nShe's just my kind o",
#  "e could be mine?  \nShe's just my kind of",
#  " could be mine?  \nShe's just my kind of ",
#  "could be mine?  \nShe's just my kind of g",
#  "ould be mine?  \nShe's just my kind of gi",
#  "uld be mine?  \nShe's just my kind of gir",
#  "ld be mine?  \nShe's just my kind of girl",
#  "d be mine?  \nShe's just my kind of girl,",
#  " be mine?  \nShe's just my kind of girl, ",
#  "be mine?  \nShe's just my kind of girl, w",
#  "e mine?  \nShe's just my kind of girl, wi",
#  " mine?  \nShe's just my kind of girl, wit",
#  "mine?  \nShe's just my kind of girl, with",
#  "ine?  \nShe's just my kind of girl, witho",
#  "ne?  \nShe's just my kind of girl, withou",
#  "e?  \nShe's just my kind of girl, without",
#  "?  \nShe's just my kind of girl, without ",
#  "  \nShe's just my kind of girl, without h",
#  " \nShe's just my kind of girl, without he",
#  "\nShe's just my kind of girl, without her",
#  "She's just my kind of girl, without her ",
#  "he's just my kind of girl, without her I",
#  "e's just my kind of girl, without her I'",
#  "'s just my kind of girl, without her I'm",
#  "s just my kind of girl, without her I'm ",
#  " just my kind of girl, without her I'm b",
#  "just my kind of girl, without her I'm bl",
#  "ust my kind of girl, without her I'm blu",
#  "st my kind of girl, without her I'm blue",
#  "t my kind of girl, without her I'm blue ",
#  " my kind of girl, without her I'm blue  ",
#  "my kind of girl, without her I'm blue  \n",
#  "y kind of girl, without her I'm blue  \nA",
#  " kind of girl, without her I'm blue  \nAn",
#  "kind of girl, without her I'm blue  \nAnd",
#  "ind of girl, without her I'm blue  \nAnd ",
#  "nd of girl, without her I'm blue  \nAnd i",
#  "d of girl, without her I'm blue  \nAnd if",
#  " of girl, without her I'm blue  \nAnd if ",
#  "of girl, without her I'm blue  \nAnd if s",
#  "f girl, without her I'm blue  \nAnd if sh",
#  " girl, without her I'm blue  \nAnd if she",
#  "girl, without her I'm blue  \nAnd if she ",
#  "irl, without her I'm blue  \nAnd if she e",
#  "rl, without her I'm blue  \nAnd if she ev",
#  "l, without her I'm blue  \nAnd if she eve",
#  ", without her I'm blue  \nAnd if she ever",
#  " without her I'm blue  \nAnd if she ever ",
#  "without her I'm blue  \nAnd if she ever l",
#  "ithout her I'm blue  \nAnd if she ever le",
#  "thout her I'm blue  \nAnd if she ever lea",
#  "hout her I'm blue  \nAnd if she ever leav",
#  "out her I'm blue  \nAnd if she ever leave",
#  "ut her I'm blue  \nAnd if she ever leaves",
#  "t her I'm blue  \nAnd if she ever leaves ",
#  " her I'm blue  \nAnd if she ever leaves m",
#  "her I'm blue  \nAnd if she ever leaves me",
#  "er I'm blue  \nAnd if she ever leaves me ",
#  "r I'm blue  \nAnd if she ever leaves me w",
#  " I'm blue  \nAnd if she ever leaves me wh",
#  "I'm blue  \nAnd if she ever leaves me wha",
#  "'m blue  \nAnd if she ever leaves me what",
#  'm blue  \nAnd if she ever leaves me what ',
#  ' blue  \nAnd if she ever leaves me what c',
#  'blue  \nAnd if she ever leaves me what co',
#  'lue  \nAnd if she ever leaves me what cou',
#  'ue  \nAnd if she ever leaves me what coul',
#  'e  \nAnd if she ever leaves me what could',
#  '  \nAnd if she ever leaves me what could ',
#  ' \nAnd if she ever leaves me what could I',
#  '\nAnd if she ever leaves me what could I ',
#  'And if she ever leaves me what could I d',
#  'nd if she ever leaves me what could I do',
#  'd if she ever leaves me what could I do,',
#  ' if she ever leaves me what could I do, ',
#  'if she ever leaves me what could I do, w',
#  'f she ever leaves me what could I do, wh',
#  ' she ever leaves me what could I do, wha',
#  'she ever leaves me what could I do, what',
#  'he ever leaves me what could I do, what ',
#  'e ever leaves me what could I do, what c',
#  ' ever leaves me what could I do, what co',
#  'ever leaves me what could I do, what cou',
#  'ver leaves me what could I do, what coul',
#  'er leaves me what could I do, what could',
#  'r leaves me what could I do, what could ',
#  ' leaves me what could I do, what could I',
#  'leaves me what could I do, what could I ',
#  'eaves me what could I do, what could I d',
#  'aves me what could I do, what could I do',
#  'ves me what could I do, what could I do?',
#  'es me what could I do, what could I do?\n',
#  's me what could I do, what could I do?\n\n',
#  ' me what could I do, what could I do?\n\nT',
#  'me what could I do, what could I do?\n\nTa',
#  'e what could I do, what could I do?\n\nTak',
#  ' what could I do, what could I do?\n\nTake',
#  'what could I do, what could I do?\n\nTake ',
#  'hat could I do, what could I do?\n\nTake i',
#  'at could I do, what could I do?\n\nTake it',
#  't could I do, what could I do?\n\nTake it ',
#  ' could I do, what could I do?\n\nTake it e',
#  'could I do, what could I do?\n\nTake it ea',
#  'ould I do, what could I do?\n\nTake it eas',
#  'uld I do, what could I do?\n\nTake it easy',
#  'ld I do, what could I do?\n\nTake it easy ',
#  'd I do, what could I do?\n\nTake it easy w',
#  ' I do, what could I do?\n\nTake it easy wi',
#  'I do, what could I do?\n\nTake it easy wit',
#  ' do, what could I do?\n\nTake it easy with',
#  'do, what could I do?\n\nTake it easy with ',
#  'o, what could I do?\n\nTake it easy with m',
#  ', what could I do?\n\nTake it easy with me',
#  ' what could I do?\n\nTake it easy with me,',
#  'what could I do?\n\nTake it easy with me, ',
#  'hat could I do?\n\nTake it easy with me, p',
#  'at could I do?\n\nTake it easy with me, pl',
#  't could I do?\n\nTake it easy with me, ple',
#  ' could I do?\n\nTake it easy with me, plea',
#  'could I do?\n\nTake it easy with me, pleas',
#  'ould I do?\n\nTake it easy with me, please',
#  'uld I do?\n\nTake it easy with me, please ',
#  'ld I do?\n\nTake it easy with me, please  ',
#  'd I do?\n\nTake it easy with me, please  \n',
#  ' I do?\n\nTake it easy with me, please  \nT',
#  'I do?\n\nTake it easy with me, please  \nTo',
#  ' do?\n\nTake it easy with me, please  \nTou',
#  'do?\n\nTake it easy with me, please  \nTouc',
#  'o?\n\nTake it easy with me, please  \nTouch',
#  '?\n\nTake it easy with me, please  \nTouch ',
#  '\n\nTake it easy with me, please  \nTouch m',
#  '\nTake it easy with me, please  \nTouch me',
#  'Take it easy with me, please  \nTouch me ',
#  'ake it easy with me, please  \nTouch me g',
#  'ke it easy with me, please  \nTouch me ge',
#  'e it easy with me, please  \nTouch me gen',
#  ' it easy with me, please  \nTouch me gent',
#  'it easy with me, please  \nTouch me gentl',
#  't easy with me, please  \nTouch me gently',
#  ' easy with me, please  \nTouch me gently ',
#  'easy with me, please  \nTouch me gently l',
#  'asy with me, please  \nTouch me gently li',
#  'sy with me, please  \nTouch me gently lik',
#  'y with me, please  \nTouch me gently like',
#  ' with me, please  \nTouch me gently like ',
#  'with me, please  \nTouch me gently like a',
#  'ith me, please  \nTouch me gently like a ',
#  'th me, please  \nTouch me gently like a s',
#  'h me, please  \nTouch me gently like a su',
#  ' me, please  \nTouch me gently like a sum',
#  'me, please  \nTouch me gently like a summ',
#  'e, please  \nTouch me gently like a summe',
#  ', please  \nTouch me gently like a summer',
#  ' please  \nTouch me gently like a summer ',
#  'please  \nTouch me gently like a summer e',
#  'lease  \nTouch me gently like a summer ev',
#  'ease  \nTouch me gently like a summer eve',
#  'ase  \nTouch me gently like a summer even',
#  'se  \nTouch me gently like a summer eveni',
#  'e  \nTouch me gently like a summer evenin',
#  '  \nTouch me gently like a summer evening',
#  ' \nTouch me gently like a summer evening ',
#  '\nTouch me gently like a summer evening b',
#  'Touch me gently like a summer evening br',
#  'ouch me gently like a summer evening bre',
#  'uch me gently like a summer evening bree',
#  'ch me gently like a summer evening breez',
#  'h me gently like a summer evening breeze',
#  ' me gently like a summer evening breeze ',
#  'me gently like a summer evening breeze  ',
#  'e gently like a summer evening breeze  \n',
#  ' gently like a summer evening breeze  \nT',
#  'gently like a summer evening breeze  \nTa',
#  'ently like a summer evening breeze  \nTak',
#  'ntly like a summer evening breeze  \nTake',
#  'tly like a summer evening breeze  \nTake ',
#  'ly like a summer evening breeze  \nTake y',
#  'y like a summer evening breeze  \nTake yo',
#  ' like a summer evening breeze  \nTake you',
#  'like a summer evening breeze  \nTake your',
#  'ike a summer evening breeze  \nTake your ',
#  'ke a summer evening breeze  \nTake your t',
#  'e a summer evening breeze  \nTake your ti',
#  ' a summer evening breeze  \nTake your tim',
#  'a summer evening breeze  \nTake your time',
#  ' summer evening breeze  \nTake your time,',
#  'summer evening breeze  \nTake your time, ',
#  'ummer evening breeze  \nTake your time, m',
#  'mmer evening breeze  \nTake your time, ma',
#  'mer evening breeze  \nTake your time, mak',
#  'er evening breeze  \nTake your time, make',
#  'r evening breeze  \nTake your time, make ',
#  ' evening breeze  \nTake your time, make i',
#  'evening breeze  \nTake your time, make it',
#  'vening breeze  \nTake your time, make it ',
#  'ening breeze  \nTake your time, make it s',
#  'ning breeze  \nTake your time, make it sl',
#  'ing breeze  \nTake your time, make it slo',
#  'ng breeze  \nTake your time, make it slow',
#  'g breeze  \nTake your time, make it slow ',
#  ' breeze  \nTake your time, make it slow  ',
#  'breeze  \nTake your time, make it slow  \n',
#  'reeze  \nTake your time, make it slow  \nA',
#  'eeze  \nTake your time, make it slow  \nAn',
#  'eze  \nTake your time, make it slow  \nAnd',
#  'ze  \nTake your time, make it slow  \nAnda',
#  'e  \nTake your time, make it slow  \nAndan',
#  '  \nTake your time, make it slow  \nAndant',
#  ' \nTake your time, make it slow  \nAndante',
#  '\nTake your time, make it slow  \nAndante,',
#  'Take your time, make it slow  \nAndante, ',
#  'ake your time, make it slow  \nAndante, A',
#  'ke your time, make it slow  \nAndante, An',
#  'e your time, make it slow  \nAndante, And',
#  ' your time, make it slow  \nAndante, Anda',
#  'your time, make it slow  \nAndante, Andan',
#  'our time, make it slow  \nAndante, Andant',
#  'ur time, make it slow  \nAndante, Andante',
#  'r time, make it slow  \nAndante, Andante ',
#  ' time, make it slow  \nAndante, Andante  ',
#  'time, make it slow  \nAndante, Andante  \n',
#  'ime, make it slow  \nAndante, Andante  \nJ',
#  'me, make it slow  \nAndante, Andante  \nJu',
#  'e, make it slow  \nAndante, Andante  \nJus',
#  ', make it slow  \nAndante, Andante  \nJust',
#  ' make it slow  \nAndante, Andante  \nJust ',
#  'make it slow  \nAndante, Andante  \nJust l',
#  'ake it slow  \nAndante, Andante  \nJust le',
#  'ke it slow  \nAndante, Andante  \nJust let',
#  'e it slow  \nAndante, Andante  \nJust let ',
#  ' it slow  \nAndante, Andante  \nJust let t',
#  'it slow  \nAndante, Andante  \nJust let th',
#  't slow  \nAndante, Andante  \nJust let the',
#  ' slow  \nAndante, Andante  \nJust let the ',
#  'slow  \nAndante, Andante  \nJust let the f',
#  'low  \nAndante, Andante  \nJust let the fe',
#  'ow  \nAndante, Andante  \nJust let the fee',
#  'w  \nAndante, Andante  \nJust let the feel',
#  '  \nAndante, Andante  \nJust let the feeli',
#  ' \nAndante, Andante  \nJust let the feelin',
#  '\nAndante, Andante  \nJust let the feeling',
#  'Andante, Andante  \nJust let the feeling ',
#  'ndante, Andante  \nJust let the feeling g',
#  'dante, Andante  \nJust let the feeling gr',
#  'ante, Andante  \nJust let the feeling gro',
#  'nte, Andante  \nJust let the feeling grow',
#  'te, Andante  \nJust let the feeling grow ',
#  'e, Andante  \nJust let the feeling grow  ',
#  ', Andante  \nJust let the feeling grow  \n',
#  ' Andante  \nJust let the feeling grow  \n ',
#  'Andante  \nJust let the feeling grow  \n  ',
#  'ndante  \nJust let the feeling grow  \n  \n',
#  'dante  \nJust let the feeling grow  \n  \nM',
#  'ante  \nJust let the feeling grow  \n  \nMa',
#  'nte  \nJust let the feeling grow  \n  \nMak',
#  'te  \nJust let the feeling grow  \n  \nMake',
#  'e  \nJust let the feeling grow  \n  \nMake ',
#  '  \nJust let the feeling grow  \n  \nMake y',
#  ' \nJust let the feeling grow  \n  \nMake yo',
#  '\nJust let the feeling grow  \n  \nMake you',
#  'Just let the feeling grow  \n  \nMake your',
#  'ust let the feeling grow  \n  \nMake your ',
#  'st let the feeling grow  \n  \nMake your f',
#  't let the feeling grow  \n  \nMake your fi',
#  ' let the feeling grow  \n  \nMake your fin',
#  'let the feeling grow  \n  \nMake your fing',
#  'et the feeling grow  \n  \nMake your finge',
#  't the feeling grow  \n  \nMake your finger',
#  ' the feeling grow  \n  \nMake your fingers',
#  'the feeling grow  \n  \nMake your fingers ',
#  'he feeling grow  \n  \nMake your fingers s',
#  'e feeling grow  \n  \nMake your fingers so',
#  ' feeling grow  \n  \nMake your fingers sof',
#  'feeling grow  \n  \nMake your fingers soft',
#  'eeling grow  \n  \nMake your fingers soft ',
#  'eling grow  \n  \nMake your fingers soft a',
#  'ling grow  \n  \nMake your fingers soft an',
#  'ing grow  \n  \nMake your fingers soft and',
#  'ng grow  \n  \nMake your fingers soft and ',
#  'g grow  \n  \nMake your fingers soft and l',
#  ' grow  \n  \nMake your fingers soft and li',
#  'grow  \n  \nMake your fingers soft and lig',
#  'row  \n  \nMake your fingers soft and ligh',
#  'ow  \n  \nMake your fingers soft and light',
#  'w  \n  \nMake your fingers soft and light ',
#  '  \n  \nMake your fingers soft and light  ',
#  ' \n  \nMake your fingers soft and light  \n',
#  '\n  \nMake your fingers soft and light  \nL',
#  '  \nMake your fingers soft and light  \nLe',
#  ' \nMake your fingers soft and light  \nLet',
#  '\nMake your fingers soft and light  \nLet ',
#  'Make your fingers soft and light  \nLet y',
#  'ake your fingers soft and light  \nLet yo',
#  'ke your fingers soft and light  \nLet you',
#  'e your fingers soft and light  \nLet your',
#  ' your fingers soft and light  \nLet your ',
#  'your fingers soft and light  \nLet your b',
#  'our fingers soft and light  \nLet your bo',
#  'ur fingers soft and light  \nLet your bod',
#  'r fingers soft and light  \nLet your body',
#  ' fingers soft and light  \nLet your body ',
#  'fingers soft and light  \nLet your body b',
#  'ingers soft and light  \nLet your body be',
#  'ngers soft and light  \nLet your body be ',
#  'gers soft and light  \nLet your body be t',
#  'ers soft and light  \nLet your body be th',
#  'rs soft and light  \nLet your body be the',
#  's soft and light  \nLet your body be the ',
#  ' soft and light  \nLet your body be the v',
#  'soft and light  \nLet your body be the ve',
#  'oft and light  \nLet your body be the vel',
#  'ft and light  \nLet your body be the velv',
#  't and light  \nLet your body be the velve',
#  ' and light  \nLet your body be the velvet',
#  'and light  \nLet your body be the velvet ',
#  'nd light  \nLet your body be the velvet o',
#  'd light  \nLet your body be the velvet of',
#  ' light  \nLet your body be the velvet of ',
#  'light  \nLet your body be the velvet of t',
#  'ight  \nLet your body be the velvet of th',
#  'ght  \nLet your body be the velvet of the',
#  'ht  \nLet your body be the velvet of the ',
#  't  \nLet your body be the velvet of the n',
#  '  \nLet your body be the velvet of the ni',
#  ' \nLet your body be the velvet of the nig',
#  '\nLet your body be the velvet of the nigh',
#  'Let your body be the velvet of the night',
#  'et your body be the velvet of the night ',
#  't your body be the velvet of the night  ',
#  ' your body be the velvet of the night  \n',
#  'your body be the velvet of the night  \nT',
#  'our body be the velvet of the night  \nTo',
#  'ur body be the velvet of the night  \nTou',
#  'r body be the velvet of the night  \nTouc',
#  ' body be the velvet of the night  \nTouch',
#  'body be the velvet of the night  \nTouch ',
#  'ody be the velvet of the night  \nTouch m',
#  'dy be the velvet of the night  \nTouch my',
#  'y be the velvet of the night  \nTouch my ',
#  ' be the velvet of the night  \nTouch my s',
#  'be the velvet of the night  \nTouch my so',
#  'e the velvet of the night  \nTouch my sou',
#  ' the velvet of the night  \nTouch my soul',
#  'the velvet of the night  \nTouch my soul,',
#  'he velvet of the night  \nTouch my soul, ',
#  'e velvet of the night  \nTouch my soul, y',
#  ' velvet of the night  \nTouch my soul, yo',
#  'velvet of the night  \nTouch my soul, you',
#  'elvet of the night  \nTouch my soul, you ',
#  'lvet of the night  \nTouch my soul, you k',
#  'vet of the night  \nTouch my soul, you kn',
#  'et of the night  \nTouch my soul, you kno',
#  't of the night  \nTouch my soul, you know',
#  ' of the night  \nTouch my soul, you know ',
#  'of the night  \nTouch my soul, you know h',
#  'f the night  \nTouch my soul, you know ho',
#  ' the night  \nTouch my soul, you know how',
#  'the night  \nTouch my soul, you know how ',
#  'he night  \nTouch my soul, you know how  ',
#  'e night  \nTouch my soul, you know how  \n',
#  ' night  \nTouch my soul, you know how  \nA',
#  'night  \nTouch my soul, you know how  \nAn',
#  'ight  \nTouch my soul, you know how  \nAnd',
#  'ght  \nTouch my soul, you know how  \nAnda',
#  'ht  \nTouch my soul, you know how  \nAndan',
#  't  \nTouch my soul, you know how  \nAndant',
#  '  \nTouch my soul, you know how  \nAndante',
#  ' \nTouch my soul, you know how  \nAndante,',
#  '\nTouch my soul, you know how  \nAndante, ',
#  'Touch my soul, you know how  \nAndante, A',
#  'ouch my soul, you know how  \nAndante, An',
#  ...]

# %%
next_char
# Out:
# [' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  ' ',
#  'i',
#  't',
#  ' ',
#  'm',
#  'e',
#  'a',
#  'n',
#  's',
#  ' ',
#  's',
#  'o',
#  'm',
#  'e',
#  't',
#  'h',
#  'i',
#  'n',
#  'g',
#  ' ',
#  's',
#  'p',
#  'e',
#  'c',
#  'i',
#  'a',
#  'l',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'L',
#  'o',
#  'o',
#  'k',
#  ' ',
#  'a',
#  't',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'w',
#  'a',
#  'y',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  's',
#  'm',
#  'i',
#  'l',
#  'e',
#  's',
#  ' ',
#  'w',
#  'h',
#  'e',
#  'n',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  's',
#  'e',
#  'e',
#  's',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'H',
#  'o',
#  'w',
#  ' ',
#  'l',
#  'u',
#  'c',
#  'k',
#  'y',
#  ' ',
#  'c',
#  'a',
#  'n',
#  ' ',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'f',
#  'e',
#  'l',
#  'l',
#  'o',
#  'w',
#  ' ',
#  'b',
#  'e',
#  '?',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  'S',
#  'h',
#  'e',
#  "'",
#  's',
#  ' ',
#  'j',
#  'u',
#  's',
#  't',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  'k',
#  'i',
#  'n',
#  'd',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'g',
#  'i',
#  'r',
#  'l',
#  ',',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'm',
#  'a',
#  'k',
#  'e',
#  's',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  'f',
#  'e',
#  'e',
#  'l',
#  ' ',
#  'f',
#  'i',
#  'n',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'W',
#  'h',
#  'o',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'r',
#  ' ',
#  'b',
#  'e',
#  'l',
#  'i',
#  'e',
#  'v',
#  'e',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  'm',
#  'i',
#  'n',
#  'e',
#  '?',
#  ' ',
#  ' ',
#  '\n',
#  'S',
#  'h',
#  'e',
#  "'",
#  's',
#  ' ',
#  'j',
#  'u',
#  's',
#  't',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  'k',
#  'i',
#  'n',
#  'd',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'g',
#  'i',
#  'r',
#  'l',
#  ',',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  'o',
#  'u',
#  't',
#  ' ',
#  'h',
#  'e',
#  'r',
#  ' ',
#  'I',
#  "'",
#  'm',
#  ' ',
#  'b',
#  'l',
#  'u',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  ' ',
#  'i',
#  'f',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'r',
#  ' ',
#  'l',
#  'e',
#  'a',
#  'v',
#  'e',
#  's',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'I',
#  ' ',
#  'd',
#  'o',
#  ',',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'I',
#  ' ',
#  'd',
#  'o',
#  '?',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  ' ',
#  'w',
#  'h',
#  'e',
#  'n',
#  ' ',
#  'w',
#  'e',
#  ' ',
#  'g',
#  'o',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  'a',
#  ' ',
#  'w',
#  'a',
#  'l',
#  'k',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'p',
#  'a',
#  'r',
#  'k',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'h',
#  'o',
#  'l',
#  'd',
#  's',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  's',
#  'q',
#  'u',
#  'e',
#  'e',
#  'z',
#  'e',
#  's',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  'h',
#  'a',
#  'n',
#  'd',
#  ' ',
#  ' ',
#  '\n',
#  'W',
#  'e',
#  "'",
#  'l',
#  'l',
#  ' ',
#  'g',
#  'o',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  'w',
#  'a',
#  'l',
#  'k',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'f',
#  'o',
#  'r',
#  ' ',
#  'h',
#  'o',
#  'u',
#  'r',
#  's',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  't',
#  'a',
#  'l',
#  'k',
#  'i',
#  'n',
#  'g',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'b',
#  'o',
#  'u',
#  't',
#  ' ',
#  'a',
#  'l',
#  'l',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  't',
#  'h',
#  'i',
#  'n',
#  'g',
#  's',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'w',
#  'e',
#  ' ',
#  'p',
#  'l',
#  'a',
#  'n',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  'S',
#  'h',
#  'e',
#  "'",
#  's',
#  ' ',
#  'j',
#  'u',
#  's',
#  't',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  'k',
#  'i',
#  'n',
#  'd',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'g',
#  'i',
#  'r',
#  'l',
#  ',',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'm',
#  'a',
#  'k',
#  'e',
#  's',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  'f',
#  'e',
#  'e',
#  'l',
#  ' ',
#  'f',
#  'i',
#  'n',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'W',
#  'h',
#  'o',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'r',
#  ' ',
#  'b',
#  'e',
#  'l',
#  'i',
#  'e',
#  'v',
#  'e',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  'm',
#  'i',
#  'n',
#  'e',
#  '?',
#  ' ',
#  ' ',
#  '\n',
#  'S',
#  'h',
#  'e',
#  "'",
#  's',
#  ' ',
#  'j',
#  'u',
#  's',
#  't',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  'k',
#  'i',
#  'n',
#  'd',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'g',
#  'i',
#  'r',
#  'l',
#  ',',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  'o',
#  'u',
#  't',
#  ' ',
#  'h',
#  'e',
#  'r',
#  ' ',
#  'I',
#  "'",
#  'm',
#  ' ',
#  'b',
#  'l',
#  'u',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  ' ',
#  'i',
#  'f',
#  ' ',
#  's',
#  'h',
#  'e',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'r',
#  ' ',
#  'l',
#  'e',
#  'a',
#  'v',
#  'e',
#  's',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'I',
#  ' ',
#  'd',
#  'o',
#  ',',
#  ' ',
#  'w',
#  'h',
#  'a',
#  't',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'l',
#  'd',
#  ' ',
#  'I',
#  ' ',
#  'd',
#  'o',
#  '?',
#  '\n',
#  '\n',
#  'T',
#  'a',
#  'k',
#  'e',
#  ' ',
#  'i',
#  't',
#  ' ',
#  'e',
#  'a',
#  's',
#  'y',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  ' ',
#  'm',
#  'e',
#  ',',
#  ' ',
#  'p',
#  'l',
#  'e',
#  'a',
#  's',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'T',
#  'o',
#  'u',
#  'c',
#  'h',
#  ' ',
#  'm',
#  'e',
#  ' ',
#  'g',
#  'e',
#  'n',
#  't',
#  'l',
#  'y',
#  ' ',
#  'l',
#  'i',
#  'k',
#  'e',
#  ' ',
#  'a',
#  ' ',
#  's',
#  'u',
#  'm',
#  'm',
#  'e',
#  'r',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'n',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'b',
#  'r',
#  'e',
#  'e',
#  'z',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'T',
#  'a',
#  'k',
#  'e',
#  ' ',
#  'y',
#  'o',
#  'u',
#  'r',
#  ' ',
#  't',
#  'i',
#  'm',
#  'e',
#  ',',
#  ' ',
#  'm',
#  'a',
#  'k',
#  'e',
#  ' ',
#  'i',
#  't',
#  ' ',
#  's',
#  'l',
#  'o',
#  'w',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  'a',
#  'n',
#  't',
#  'e',
#  ',',
#  ' ',
#  'A',
#  'n',
#  'd',
#  'a',
#  'n',
#  't',
#  'e',
#  ' ',
#  ' ',
#  '\n',
#  'J',
#  'u',
#  's',
#  't',
#  ' ',
#  'l',
#  'e',
#  't',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'f',
#  'e',
#  'e',
#  'l',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'g',
#  'r',
#  'o',
#  'w',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  'M',
#  'a',
#  'k',
#  'e',
#  ' ',
#  'y',
#  'o',
#  'u',
#  'r',
#  ' ',
#  'f',
#  'i',
#  'n',
#  'g',
#  'e',
#  'r',
#  's',
#  ' ',
#  's',
#  'o',
#  'f',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'l',
#  'i',
#  'g',
#  'h',
#  't',
#  ' ',
#  ' ',
#  '\n',
#  'L',
#  'e',
#  't',
#  ' ',
#  'y',
#  'o',
#  'u',
#  'r',
#  ' ',
#  'b',
#  'o',
#  'd',
#  'y',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'v',
#  'e',
#  'l',
#  'v',
#  'e',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'n',
#  'i',
#  'g',
#  'h',
#  't',
#  ' ',
#  ' ',
#  '\n',
#  'T',
#  'o',
#  'u',
#  'c',
#  'h',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  's',
#  'o',
#  'u',
#  'l',
#  ',',
#  ' ',
#  'y',
#  'o',
#  'u',
#  ' ',
#  'k',
#  'n',
#  'o',
#  'w',
#  ' ',
#  'h',
#  'o',
#  'w',
#  ' ',
#  ' ',
#  '\n',
#  'A',
#  'n',
#  'd',
#  'a',
#  'n',
#  't',
#  'e',
#  ',',
#  ' ',
#  'A',
#  'n',
#  'd',
#  ...]

# %%
X=np.zeros((len(sentences),maxlen,vocab_size))
y=np.zeros((len(sentences),vocab_size))
for ix in range(len(sentences)):
    y[ix,char_ix[next_char[ix]]]=1
    for iy in range(maxlen):
        X[ix,iy,char_ix[sentences[ix][iy]]]=1

# %%
X

# %%
y

# %%
model=Sequential()
model.add(LSTM(128,input_shape=(maxlen,vocab_size)))
model.add(Dense(vocab_size))
model.add(Activation('softmax'))
model.summary()
model.compile(optimizer=Adam(lr=0.01),loss='categorical_crossentropy')

# %%
model.fit(X,y,epochs=100,batch_size=128)

# %%
#serialize model to JSON  serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
import random
txt = corpus
generated=''
start_index=random.randint(0,len(txt)-maxlen-1)
sent=txt[start_index:start_index+maxlen]
generated+=sent
for i in range(1900):
    x_sample=generated[i:i+maxlen]
    x=np.zeros((1,maxlen,vocab_size))
    for j in range(maxlen):
        x[0,j,char_ix[x_sample[j]]]=1
    probs=model.predict(x)
    probs=np.reshape(probs,probs.shape[1])
    ix=np.random.choice(range(vocab_size),p=probs.ravel())
    generated+=ix_char[ix]

# %%
print(generated)
# Out:
#  strangers and a friend.\nCame to my mind math\nI love on himber\nAny onles this keep that arong take it but nean\nJust you're hrouper\n\nYou told you\'re try lafe will, oh?\nAnd rold of the signes birdere\nBean blaabe dreeps\n'Cause I\'ll world up as last to try one are new now\n\n\n\n\n\nSo friend in eAre\nKeep the thy one and lookin\' and hont quint share I'll giving on wo where that moge\nLay it all on mint turn you're all the same\nWe make me back layss marte will leave some shoulder bab\nThear heart, she ton't harts is these back this esed\nWhere again tolat time latbe stt gal\nHon\nFill gone from and baby more\n\nGavery tight on this these in a remer\n\nNat wrappe uping love mich, needy Ah the gothone now['be nyes but time, day the rase\nBut I know I fill beth like you can't ever\nNo hor le don't love you do\nAll the coiring to les me abouth tone this friend\nThe flace (leas\nBreake long, ont oh the everybort can\'t is, out song, that it not\n\nNo\nBurns too\n\nNo houpare where that a lonely falling throutis now\nBeay chise, I wish some manyy\nIt sing about mone\n\n\n\n\n\nAnd stace secrust the sarted the only\'s\nI sagiotell tonight barceren if you are mitting me and I’ver ’s wrie\nSing a thinn you be all this things what we\'re prest and want to so don't just now\n\nRealling the are\nI'll put my try subcoy, been lonely shinking deepliss\nOf me proll ong too here, lookin thinging chan't if men we picter\nGlad to stare, sears, you en try take it rismpulle that I'll sing anlwn here fror sing through or things I'll be alone\n\nLay it all over takes\nAnd I keen we lonely\nArl of the roand at you hoter\nYou're just arlt mure in the the sky\nBut my fall on the secoto\nSomewill be shene,\ncip to streadin\nAnd froght\oCAme, back coulper't eserether last will now\n\nWanca side the roalt like\nI told me a plrser\nI know in the sim\nYou goes that' on the slace song, could never ton that sitting lan it all thro
