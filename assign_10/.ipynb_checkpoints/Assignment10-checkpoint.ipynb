# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.metrics import mean_squared_error
from hmmlearn import hmm
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-15b4c8f57d05> in <module>
#       3 from matplotlib import pyplot as plt
#       4 from datetime import datetime
# ----> 5 from keras.models import Sequential
#       6 from keras.layers import Dense
#       7 from keras.layers import LSTM
#
# ~/anaconda3/lib/python3.6/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/anaconda3/lib/python3.6/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~/anaconda3/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>
#       1 from six.moves import range
#       2 import numpy as np
# ----> 3 from .. import backend as K
#       4
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/__init__.py in <module>
#      81 elif _BACKEND == 'tensorflow':
#      82     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 83     from .tensorflow_backend import *
#      84 else:
#      85     raise ValueError('Unknown backend: ' + str(_BACKEND))
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow.python.training import moving_averages
#       3 from tensorflow.python.ops import tensor_array_ops
#       4 from tensorflow.python.ops import control_flow_ops
#       5 from tensorflow.python.ops import functional_ops
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
time_series = pd.read_csv("GoogleStocks.csv", parse_dates=True)
time_series = time_series.drop(time_series.index[0])

# %%
time_series.head()
# Out:
#          date      close        volume       open       high        low
# 1  2019/03/26  1184.6200  1894639.0000  1198.5300  1202.8300  1176.7200
# 2  2019/03/25  1193.0000  1493841.0000  1196.9300  1206.3975  1187.0400
# 3  2019/03/22  1205.5000  1668910.0000  1226.3200  1230.0000  1202.8250
# 4  2019/03/21  1231.5400  1195899.0000  1216.0000  1231.7900  1213.1500
# 5  2019/03/20  1223.9700  2089367.0000  1197.3500  1227.1400  1196.1700

# %%
time_series['high'] = pd.to_numeric(time_series['high'])
time_series['low'] = pd.to_numeric(time_series['low'])
time_series['average'] = (time_series['high'] + time_series['low']) / 2
time_series = time_series.sort_values('date')
time_series.head()
# Out:
#            date     close        volume      open    high     low  average
# 755  2016/03/28  733.5300  1300817.0000  736.7900  738.99  732.50  735.745
# 754  2016/03/29  744.7700  1902254.0000  734.5900  747.25  728.76  738.005
# 753  2016/03/30  750.5300  1782278.0000  750.1000  757.88  748.74  753.310
# 752  2016/03/31  744.9500  1718638.0000  749.2500  750.85  740.94  745.895
# 751  2016/04/01  749.9100  1576240.0000  738.6000  750.34  737.00  743.670

# %%
columns = list(time_series.columns.values)
del columns[0]
fig = plt.figure()
plt.style.use('fivethirtyeight')
for i, column in enumerate(columns):
    plt.subplot(len(columns), 1, i + 1)
    plt.plot(time_series.index, time_series[column])
    plt.title(column, y=0.5, loc='right')
plt.show()

# %%
time_series.isna().any()
data = time_series[['open', 'average', 'volume']]
# Feature Scaling Normalization
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(data)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float64, object were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
def create_dataset(data, time_stamp):
    X_train = []
    y_train = []
    print("Time stamp: {0}".format(time_stamp))
    for i in range(time_stamp, len(data)):
        X_train.append(
            np.array([data[i - time_stamp:i, 1], data[i - time_stamp:i, 2]]).T)
        y_train.append(data[i, 0])
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    return X_train[:-100], y_train[:-100], X_train[-100:], y_train[-100:]

# %%
def create_model(number_of_layer, number_of_cells, input_shape):
    model = Sequential()
    model.add(
        LSTM(
            units=number_of_cells,
            return_sequences=True,
            input_shape=input_shape))
    input_shape=None
    model.add(Dropout(0.2))
    for l in range(number_of_layer - 1):
        return_sequence = True
        if(l==number_of_layer - 2):
            return_sequence = False
        model.add(
            LSTM(
                units=number_of_cells,
                return_sequences=return_sequence))
        model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer = 'adam', loss = 'mean_squared_error')
    return model

# %%
def run_model(data, number_of_layer, number_of_cells, time_stamp):
    X_train, y_train, X_test, y_test = create_dataset(data, time_stamp)
    print("X train shape: {0}, y_train shape: {1}".format(X_train.shape, y_train.shape))
    model = create_model(number_of_layer, number_of_cells, (time_stamp, 2))
    print(model.summary())
    model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=False)
    predicted_open_price = model.predict(X_test)
    print("Number of layer: {0}, Number of cells: {1}, time_stamp: {2}, Mean square error :{3}".format(
        number_of_layer, number_of_cells, time_stamp, mean_squared_error(predicted_open_price, y_test)))

# %%
run_model(training_set_scaled, 2, 30, 20)
# Out:
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_31 (LSTM)               (None, 20, 30)            3960
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 20, 30)            0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 11,311
# Trainable params: 11,311
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 30, time_stamp: 20, Mean square error :0.002342835022663475

# %%
for num_layers in [2,3]:
    for num_cells in [30,50,80]:
        for time_stamp in [20,50,75]:
            run_model(training_set_scaled, num_layers, num_cells, time_stamp)
# Out:
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_33 (LSTM)               (None, 20, 30)            3960
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 20, 30)            0
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 11,311
# Trainable params: 11,311
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 30, time_stamp: 20, Mean square error :0.001784161511881381
# Time stamp: 50
# X train shape: (605, 50, 2), y_train shape: (605,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_35 (LSTM)               (None, 50, 30)            3960
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 50, 30)            0
# _________________________________________________________________
# lstm_36 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 11,311
# Trainable params: 11,311
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 30, time_stamp: 50, Mean square error :0.002433597670676655
# Time stamp: 75
# X train shape: (580, 75, 2), y_train shape: (580,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_37 (LSTM)               (None, 75, 30)            3960
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 75, 30)            0
# _________________________________________________________________
# lstm_38 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 11,311
# Trainable params: 11,311
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 30, time_stamp: 75, Mean square error :0.0018887649256876424
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_39 (LSTM)               (None, 20, 50)            10600
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 20, 50)            0
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 30,851
# Trainable params: 30,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 50, time_stamp: 20, Mean square error :0.00151157195873092
# Time stamp: 50
# X train shape: (605, 50, 2), y_train shape: (605,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_41 (LSTM)               (None, 50, 50)            10600
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 50, 50)            0
# _________________________________________________________________
# lstm_42 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 30,851
# Trainable params: 30,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 50, time_stamp: 50, Mean square error :0.003018715705092419
# Time stamp: 75
# X train shape: (580, 75, 2), y_train shape: (580,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_43 (LSTM)               (None, 75, 50)            10600
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 75, 50)            0
# _________________________________________________________________
# lstm_44 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 30,851
# Trainable params: 30,851
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 50, time_stamp: 75, Mean square error :0.0016145383398270168
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_45 (LSTM)               (None, 20, 80)            26560
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 20, 80)            0
# _________________________________________________________________
# lstm_46 (LSTM)               (None, 80)                51520
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 78,161
# Trainable params: 78,161
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 80, time_stamp: 20, Mean square error :0.001332302402410035
# Time stamp: 50
# X train shape: (605, 50, 2), y_train shape: (605,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_47 (LSTM)               (None, 50, 80)            26560
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 50, 80)            0
# _________________________________________________________________
# lstm_48 (LSTM)               (None, 80)                51520
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 78,161
# Trainable params: 78,161
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 80, time_stamp: 50, Mean square error :0.0018502751716074264
# Time stamp: 75
# X train shape: (580, 75, 2), y_train shape: (580,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_49 (LSTM)               (None, 75, 80)            26560
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 75, 80)            0
# _________________________________________________________________
# lstm_50 (LSTM)               (None, 80)                51520
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 78,161
# Trainable params: 78,161
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 2, Number of cells: 80, time_stamp: 75, Mean square error :0.001663883146031965
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_51 (LSTM)               (None, 20, 30)            3960
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 20, 30)            0
# _________________________________________________________________
# lstm_52 (LSTM)               (None, 20, 30)            7320
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 20, 30)            0
# _________________________________________________________________
# lstm_53 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,631
# Trainable params: 18,631
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 30, time_stamp: 20, Mean square error :0.002419528995342689
# Time stamp: 50
# X train shape: (605, 50, 2), y_train shape: (605,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_54 (LSTM)               (None, 50, 30)            3960
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 50, 30)            0
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 50, 30)            7320
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 50, 30)            0
# _________________________________________________________________
# lstm_56 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,631
# Trainable params: 18,631
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 30, time_stamp: 50, Mean square error :0.0021841520345853003
# Time stamp: 75
# X train shape: (580, 75, 2), y_train shape: (580,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_57 (LSTM)               (None, 75, 30)            3960
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 75, 30)            0
# _________________________________________________________________
# lstm_58 (LSTM)               (None, 75, 30)            7320
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 75, 30)            0
# _________________________________________________________________
# lstm_59 (LSTM)               (None, 30)                7320
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 18,631
# Trainable params: 18,631
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 30, time_stamp: 75, Mean square error :0.006232825623851948
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_60 (LSTM)               (None, 20, 50)            10600
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 20, 50)            0
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 20, 50)            20200
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 20, 50)            0
# _________________________________________________________________
# lstm_62 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 51,051
# Trainable params: 51,051
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 50, time_stamp: 20, Mean square error :0.001976393753888426
# Time stamp: 50
# X train shape: (605, 50, 2), y_train shape: (605,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_63 (LSTM)               (None, 50, 50)            10600
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 50, 50)            0
# _________________________________________________________________
# lstm_64 (LSTM)               (None, 50, 50)            20200
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 50, 50)            0
# _________________________________________________________________
# lstm_65 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 51,051
# Trainable params: 51,051
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 50, time_stamp: 50, Mean square error :0.002586496958320236
# Time stamp: 75
# X train shape: (580, 75, 2), y_train shape: (580,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_66 (LSTM)               (None, 75, 50)            10600
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 75, 50)            0
# _________________________________________________________________
# lstm_67 (LSTM)               (None, 75, 50)            20200
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 75, 50)            0
# _________________________________________________________________
# lstm_68 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 51,051
# Trainable params: 51,051
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 50, time_stamp: 75, Mean square error :0.002738662855074795
# Time stamp: 20
# X train shape: (635, 20, 2), y_train shape: (635,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_69 (LSTM)               (None, 20, 80)            26560
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 20, 80)            0
# _________________________________________________________________
# lstm_70 (LSTM)               (None, 20, 80)            51520
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 20, 80)            0
# _________________________________________________________________
# lstm_71 (LSTM)               (None, 80)                51520
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 129,681
# Trainable params: 129,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 80, time_stamp: 20, Mean square error :0.0018577371823794437
# Time stamp: 50
# X train shape: (605, 50, 2), y_train shape: (605,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_72 (LSTM)               (None, 50, 80)            26560
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 50, 80)            0
# _________________________________________________________________
# lstm_73 (LSTM)               (None, 50, 80)            51520
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 50, 80)            0
# _________________________________________________________________
# lstm_74 (LSTM)               (None, 80)                51520
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 129,681
# Trainable params: 129,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 80, time_stamp: 50, Mean square error :0.0016998981816302118
# Time stamp: 75
# X train shape: (580, 75, 2), y_train shape: (580,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_75 (LSTM)               (None, 75, 80)            26560
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 75, 80)            0
# _________________________________________________________________
# lstm_76 (LSTM)               (None, 75, 80)            51520
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 75, 80)            0
# _________________________________________________________________
# lstm_77 (LSTM)               (None, 80)                51520
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 129,681
# Trainable params: 129,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# Number of layer: 3, Number of cells: 80, time_stamp: 75, Mean square error :0.0016513907114493872

# %%
def hmm_model(states)
